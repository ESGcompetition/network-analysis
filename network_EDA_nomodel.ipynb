# %%
import OpenDartReader
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from itertools import combinations
import networkx as nx

# %%
api_key = 'd0d913cb52aceb226c589884da8be4006d93381c'
dart = OpenDartReader(api_key)

# %%
df = pd.DataFrame()

for k in [2020,2021,2022]:
    temp = dart.report('대신증권','임원',k)
    temp['year'] = k
    df = pd.concat([df,temp])
    
df.columns = ['접수번호', '법인구분', '고유번호', '법인명', '이름', '성별', '생년월일', '직위', '등기임원여부', '상근여부', '담당업무', '주요경력', '최대주주와의관계', '재직기간', '임기만료일', '보고서연도']
df.to_csv("./df_daishin_executive.csv", index = False)

# %%
df = pd.DataFrame()

for k in [2020,2021,2022]:
    temp = dart.report('대신증권','최대주주',k)
    temp['year'] = k
    df = pd.concat([df,temp])
    
df.columns = ['접수번호', '법인구분', '고유번호', '법인명', '주식의종류', '이름', '관계', '기초주식수', '기초주식지분율', '기말주식수', '기말주식지분율', '비고', '보고서연도']
df.to_csv("./df_daishin_shareholder.csv", index = False)

# %%
daishin_executive = pd.read_csv('./df_daishin_executive.csv', sep=",", encoding = 'UTF-8')
daishin_shareholder = pd.read_csv('./df_daishin_shareholder.csv', sep=",", encoding = 'UTF-8')

# %%
def getUniversity(x):
    return x.split('\n')[0]

def getMaster(x):
    if x.find('석사')!=-1:
        return 1
    else:
        return 0
    
def getPhD(x):
    if x.find('박사')!=-1:
        return 1
    else:
        return 0
    
daishin_executive['대학교'] = daishin_executive['주요경력'].apply(lambda x : getUniversity(x))
daishin_executive['석사여부'] = daishin_executive['주요경력'].apply(lambda x : getMaster(x))
daishin_executive['박사여부'] = daishin_executive['주요경력'].apply(lambda x : getPhD(x))

# 재직 시작일 추출
daishin_executive['시작일'] = daishin_executive['재직기간'].str.split('~').str[0]

# 재직 시작일을 연도로 변환
daishin_executive['시작일'] = pd.to_datetime(daishin_executive['시작일'], format='%Y.%m.%d')

# 현재 날짜 계산
today = pd.to_datetime('today')

# 경력 계산
daishin_executive['경력'] = (today - daishin_executive['시작일']).dt.days // 365

#임기만료까지 남은 기간
daishin_executive[['연도', '월', '일']] = daishin_executive['임기만료일'].str.extract(r'(\d{4})년 (\d{2})월 (\d{2})일')
expiration_date = pd.to_datetime(daishin_executive['연도'] + daishin_executive['월'] + daishin_executive['일'], format='%Y%m%d')
daishin_executive['임기만료까지기간'] = (expiration_date - today).dt.days

# 생년월일에서 연도와 월 추출
daishin_executive[['생년', '월']] = daishin_executive['생년월일'].str.extract(r'(\d{4})년 (\d{2})월')

# 현재 연도와 월 계산
current_year = today.year
current_month = today.month

# 만나이 계산
daishin_executive['만나이'] = current_year - daishin_executive['생년'].astype(int)
daishin_executive.loc[daishin_executive['월'].astype(int) > current_month, '만나이'] -= 1

# %%
daishin_executive.head()
# Out:
#              접수번호 법인구분    고유번호   법인명   이름 성별       생년월일  직위 등기임원여부 상근여부  ...  \
# 0  20210311001204    Y  110893  대신증권  이어룡  여  1953년 09월  회장   등기임원   상근  ...
# 1  20210311001204    Y  110893  대신증권  신인식  남  1962년 01월  전무  미등기임원   상근  ...
# 2  20210311001204    Y  110893  대신증권  길기모  남  1968년 12월  전무  미등기임원   상근  ...
# 3  20210311001204    Y  110893  대신증권  조경순  남  1964년 01월  전무  미등기임원   상근  ...
# 4  20210311001204    Y  110893  대신증권  홍대한  남  1963년 05월  전무  미등기임원   상근  ...
#
#   석사여부 박사여부        시작일  경력    연도   월   일  임기만료까지기간    생년 만나이
# 0    0    0 2004-09-24  18  2021  09  19      -787  1953  69
# 1    0    0 2013-04-01  10  2021  01  19      -787  1962  61
# 2    0    0 2019-04-01   4  2021  12  31      -775  1968  54
# 3    1    0 2014-01-01   9  2021  01  19      -787  1964  59
# 4    0    0 2014-01-01   9  2021  05  31      -500  1963  60
#
# [5 rows x 27 columns]

# %%
drop_col = ['접수번호', '법인구분','고유번호','법인명','재직기간','보고서연도','시작일', '생년월일', '생년', '월','연도','일','임기만료일' ]

# %%
daishin_executive = daishin_executive.drop(drop_col, axis=1)6

# %%
drop_col2=['주요경력', '최대주주와의관계']
daishin_executive = daishin_executive.drop(drop_col2, axis=1)

# %%
def getUniversity_name(x):
    if x.split(' ')[0] == 'University':
        return 'Bath'
    else :
        return x.split(' ')[0]
daishin_executive['대학교'] = daishin_executive['대학교'].apply(lambda x : getUniversity_name(x))

# %%
daishin_executive.head()
# Out:
#     이름 성별  직위 등기임원여부 상근여부             담당업무      대학교  석사여부  박사여부  경력  임기만료까지기간  \
# 0  이어룡  여  회장   등기임원   상근                -  상명여자사범대     0     0  18      -787
# 1  신인식  남  전무  미등기임원   상근                -     성균관대     0     0  10      -787
# 2  길기모  남  전무  미등기임원   상근         리스크관리부문장      서울대     0     0   4      -775
# 3  조경순  남  전무  미등기임원   상근           대외협력담당      연세대     1     0   9      -787
# 4  홍대한  남  전무  미등기임원   상근  준법감시인\n/준법지원부문장      서강대     0     0   9      -500
#
#    만나이
# 0   69
# 1   61
# 2   54
# 3   59
# 4   60

# %%
def commonidx(df, col, uniquevalue):
    col_index_lst=[]
    for i in range(len(uniquevalue)):
        col_i_idx = df[df[col] == uniquevalue[i]].index.tolist()
        col_index_lst.append(col_i_idx)
    return col_index_lst

# %%
sex_idx=commonidx(daishin_executive, '성별', ['여','남'])
position_idx = commonidx(daishin_executive, '직위', daishin_executive['직위'].unique().tolist())
registeredOfficer_idx = commonidx(daishin_executive, '등기임원여부', daishin_executive['등기임원여부'].unique().tolist())
fullTime_idx = commonidx(daishin_executive, '상근여부', daishin_executive['상근여부'].unique().tolist())
university_idx = commonidx(daishin_executive, '대학교', daishin_executive['대학교'].unique().tolist())
master_idx = commonidx(daishin_executive, '석사여부', daishin_executive['석사여부'].unique().tolist())
doctor_idx = commonidx(daishin_executive, '박사여부', daishin_executive['박사여부'].unique().tolist())
career_idx = commonidx(daishin_executive, '경력', daishin_executive['경력'].unique().tolist())
expiration_idx = commonidx(daishin_executive, '임기만료까지기간', daishin_executive['임기만료까지기간'].unique().tolist())
age_idx = commonidx(daishin_executive, '만나이', daishin_executive['만나이'].unique().tolist())

# %%
sex_idx[0]
# Out:
# [0, 15, 36, 50, 74, 84]

# %%
for i in sex_idx[0]:
    print(daishin_executive.loc[i,'이름'])
# Out:
# 이어룡
# 이순남
# 이어룡
# 이순남
# 이어룡
# 이순남

# %%
def idxtoname(df, idxlist):
    name_col_list = []
    for i in idxlist:
        name_list=[]
        for j in i:
            name_list.append(df.loc[j, '이름']) 
        name_col_list.append(name_list)
    return name_col_list

# %%
sex_name = idxtoname(daishin_executive, sex_idx)
position_name = idxtoname(daishin_executive, position_idx)
registeredOfficer_name = idxtoname(daishin_executive, registeredOfficer_idx)
fullTime_name = idxtoname(daishin_executive, fullTime_idx)
university_name = idxtoname(daishin_executive, university_idx)
master_name = idxtoname(daishin_executive, master_idx)
doctor_name = idxtoname(daishin_executive, doctor_idx)
career_name = idxtoname(daishin_executive, career_idx)
expiration_name = idxtoname(daishin_executive, expiration_idx)
age_name = idxtoname(daishin_executive, age_idx)

# %%
sex_name[0]
# Out:
# ['이어룡', '이순남', '이어룡', '이순남', '이어룡', '이순남']

# %%
def combinations_name(name_col_list):
    permutations_list=[]
    for i in name_col_list:
        permutations_list.append(list(combinations(i, 2)))
    return permutations_list

# %%
sex_2 = combinations_name(sex_name)
position_2 = combinations_name(position_name)
registeredOfficer_2 = combinations_name(registeredOfficer_name)
fullTime_2 = combinations_name(fullTime_name)
university_2 = combinations_name(university_name)
master_2 = combinations_name(master_name)
doctor_2 = combinations_name(doctor_name)
career_2 = combinations_name(career_name)
expiration_2 = combinations_name(expiration_name)
age_2 = combinations_name(age_name)

# %%
sex_2
# Out:
# [[('이어룡', '이순남'),
#   ('이어룡', '이어룡'),
#   ('이어룡', '이순남'),
#   ('이어룡', '이어룡'),
#   ('이어룡', '이순남'),
#   ('이순남', '이어룡'),
#   ('이순남', '이순남'),
#   ('이순남', '이어룡'),
#   ('이순남', '이순남'),
#   ('이어룡', '이순남'),
#   ('이어룡', '이어룡'),
#   ('이어룡', '이순남'),
#   ('이순남', '이어룡'),
#   ('이순남', '이순남'),
#   ('이어룡', '이순남')],
#  [('신인식', '길기모'),
#   ('신인식', '조경순'),
#   ('신인식', '홍대한'),
#   ('신인식', '이정화'),
#   ('신인식', '진승욱'),
#   ('신인식', '권택현'),
#   ('신인식', '박성준'),
#   ('신인식', '정연규'),
#   ('신인식', '정재중'),
#   ('신인식', '양홍석'),
#   ('신인식', '김호중'),
#   ('신인식', '문병식'),
#   ('신인식', '정연우'),
#   ('신인식', '임민수'),
#   ('신인식', '김수창'),
#   ('신인식', '이재우'),
#   ('신인식', '홍종국'),
#   ('신인식', '최근영'),
#   ('신인식', '김상원'),
#   ('신인식', '오익근'),
#   ('신인식', '나유석'),
#   ('신인식', '신재범'),
#   ('신인식', '강준규'),
#   ('신인식', '강윤기'),
#   ('신인식', '김성원'),
#   ('신인식', '정기동'),
#   ('신인식', '박현식'),
#   ('신인식', '이지원'),
#   ('신인식', '김병철'),
#   ('신인식', '이창세'),
#   ('신인식', '조홍희'),
#   ('신인식', '김범철'),
#   ('신인식', '송혁'),
#   ('신인식', '송혁'),
#   ('신인식', '길기모'),
#   ('신인식', '유창범'),
#   ('신인식', '박성준'),
#   ('신인식', '홍대한'),
#   ('신인식', '이정화'),
#   ('신인식', '진승욱'),
#   ('신인식', '권택현'),
#   ('신인식', '정연규'),
#   ('신인식', '김호중'),
#   ('신인식', '양홍석'),
#   ('신인식', '정연우'),
#   ('신인식', '이재우'),
#   ('신인식', '임민수'),
#   ('신인식', '김수창'),
#   ('신인식', '홍종국'),
#   ('신인식', '최근영'),
#   ('신인식', '김상원'),
#   ('신인식', '나유석'),
#   ('신인식', '신재범'),
#   ('신인식', '오익근'),
#   ('신인식', '강준규'),
#   ('신인식', '강윤기'),
#   ('신인식', '김성원'),
#   ('신인식', '박정환'),
#   ('신인식', '정기동'),
#   ('신인식', '이정훈'),
#   ('신인식', '김봉진'),
#   ('신인식', '박현식'),
#   ('신인식', '이성영'),
#   ('신인식', '김병철'),
#   ('신인식', '이창세'),
#   ('신인식', '조홍희'),
#   ('신인식', '김창수'),
#   ('신인식', '원윤희'),
#   ('신인식', '김범철'),
#   ('신인식', '송혁'),
#   ('신인식', '길기모'),
#   ('신인식', '박성준'),
#   ('신인식', '이정화'),
#   ('신인식', '권택현'),
#   ('신인식', '정연규'),
#   ('신인식', '김호중'),
#   ('신인식', '정연우'),
#   ('신인식', '이재우'),
#   ('신인식', '양홍석'),
#   ('신인식', '임민수'),
#   ('신인식', '김수창'),
#   ('신인식', '홍종국'),
#   ('신인식', '최근영'),
#   ('신인식', '김상원'),
#   ('신인식', '나유석'),
#   ('신인식', '신재범'),
#   ('신인식', '강준규'),
#   ('신인식', '강윤기'),
#   ('신인식', '김성원'),
#   ('신인식', '오익근'),
#   ('신인식', '박정환'),
#   ('신인식', '송종원'),
#   ('신인식', '김경렬'),
#   ('신인식', '김광혁'),
#   ('신인식', '박석원'),
#   ('신인식', '김성균'),
#   ('신인식', '최광철'),
#   ('신인식', '최대경'),
#   ('신인식', '이정훈'),
#   ('신인식', '김봉진'),
#   ('신인식', '김병철'),
#   ('신인식', '김상혁'),
#   ('신인식', '이성영'),
#   ('신인식', '정회민'),
#   ('신인식', '이창세'),
#   ('신인식', '김창수'),
#   ('신인식', '원윤희'),
#   ('신인식', '김성호'),
#   ('신인식', '김범철'),
#   ('길기모', '조경순'),
#   ('길기모', '홍대한'),
#   ('길기모', '이정화'),
#   ('길기모', '진승욱'),
#   ('길기모', '권택현'),
#   ('길기모', '박성준'),
#   ('길기모', '정연규'),
#   ('길기모', '정재중'),
#   ('길기모', '양홍석'),
#   ('길기모', '김호중'),
#   ('길기모', '문병식'),
#   ('길기모', '정연우'),
#   ('길기모', '임민수'),
#   ('길기모', '김수창'),
#   ('길기모', '이재우'),
#   ('길기모', '홍종국'),
#   ('길기모', '최근영'),
#   ('길기모', '김상원'),
#   ('길기모', '오익근'),
#   ('길기모', '나유석'),
#   ('길기모', '신재범'),
#   ('길기모', '강준규'),
#   ('길기모', '강윤기'),
#   ('길기모', '김성원'),
#   ('길기모', '정기동'),
#   ('길기모', '박현식'),
#   ('길기모', '이지원'),
#   ('길기모', '김병철'),
#   ('길기모', '이창세'),
#   ('길기모', '조홍희'),
#   ('길기모', '김범철'),
#   ('길기모', '송혁'),
#   ('길기모', '송혁'),
#   ('길기모', '길기모'),
#   ('길기모', '유창범'),
#   ('길기모', '박성준'),
#   ('길기모', '홍대한'),
#   ('길기모', '이정화'),
#   ('길기모', '진승욱'),
#   ('길기모', '권택현'),
#   ('길기모', '정연규'),
#   ('길기모', '김호중'),
#   ('길기모', '양홍석'),
#   ('길기모', '정연우'),
#   ('길기모', '이재우'),
#   ('길기모', '임민수'),
#   ('길기모', '김수창'),
#   ('길기모', '홍종국'),
#   ('길기모', '최근영'),
#   ('길기모', '김상원'),
#   ('길기모', '나유석'),
#   ('길기모', '신재범'),
#   ('길기모', '오익근'),
#   ('길기모', '강준규'),
#   ('길기모', '강윤기'),
#   ('길기모', '김성원'),
#   ('길기모', '박정환'),
#   ('길기모', '정기동'),
#   ('길기모', '이정훈'),
#   ('길기모', '김봉진'),
#   ('길기모', '박현식'),
#   ('길기모', '이성영'),
#   ('길기모', '김병철'),
#   ('길기모', '이창세'),
#   ('길기모', '조홍희'),
#   ('길기모', '김창수'),
#   ('길기모', '원윤희'),
#   ('길기모', '김범철'),
#   ('길기모', '송혁'),
#   ('길기모', '길기모'),
#   ('길기모', '박성준'),
#   ('길기모', '이정화'),
#   ('길기모', '권택현'),
#   ('길기모', '정연규'),
#   ('길기모', '김호중'),
#   ('길기모', '정연우'),
#   ('길기모', '이재우'),
#   ('길기모', '양홍석'),
#   ('길기모', '임민수'),
#   ('길기모', '김수창'),
#   ('길기모', '홍종국'),
#   ('길기모', '최근영'),
#   ('길기모', '김상원'),
#   ('길기모', '나유석'),
#   ('길기모', '신재범'),
#   ('길기모', '강준규'),
#   ('길기모', '강윤기'),
#   ('길기모', '김성원'),
#   ('길기모', '오익근'),
#   ('길기모', '박정환'),
#   ('길기모', '송종원'),
#   ('길기모', '김경렬'),
#   ('길기모', '김광혁'),
#   ('길기모', '박석원'),
#   ('길기모', '김성균'),
#   ('길기모', '최광철'),
#   ('길기모', '최대경'),
#   ('길기모', '이정훈'),
#   ('길기모', '김봉진'),
#   ('길기모', '김병철'),
#   ('길기모', '김상혁'),
#   ('길기모', '이성영'),
#   ('길기모', '정회민'),
#   ('길기모', '이창세'),
#   ('길기모', '김창수'),
#   ('길기모', '원윤희'),
#   ('길기모', '김성호'),
#   ('길기모', '김범철'),
#   ('조경순', '홍대한'),
#   ('조경순', '이정화'),
#   ('조경순', '진승욱'),
#   ('조경순', '권택현'),
#   ('조경순', '박성준'),
#   ('조경순', '정연규'),
#   ('조경순', '정재중'),
#   ('조경순', '양홍석'),
#   ('조경순', '김호중'),
#   ('조경순', '문병식'),
#   ('조경순', '정연우'),
#   ('조경순', '임민수'),
#   ('조경순', '김수창'),
#   ('조경순', '이재우'),
#   ('조경순', '홍종국'),
#   ('조경순', '최근영'),
#   ('조경순', '김상원'),
#   ('조경순', '오익근'),
#   ('조경순', '나유석'),
#   ('조경순', '신재범'),
#   ('조경순', '강준규'),
#   ('조경순', '강윤기'),
#   ('조경순', '김성원'),
#   ('조경순', '정기동'),
#   ('조경순', '박현식'),
#   ('조경순', '이지원'),
#   ('조경순', '김병철'),
#   ('조경순', '이창세'),
#   ('조경순', '조홍희'),
#   ('조경순', '김범철'),
#   ('조경순', '송혁'),
#   ('조경순', '송혁'),
#   ('조경순', '길기모'),
#   ('조경순', '유창범'),
#   ('조경순', '박성준'),
#   ('조경순', '홍대한'),
#   ('조경순', '이정화'),
#   ('조경순', '진승욱'),
#   ('조경순', '권택현'),
#   ('조경순', '정연규'),
#   ('조경순', '김호중'),
#   ('조경순', '양홍석'),
#   ('조경순', '정연우'),
#   ('조경순', '이재우'),
#   ('조경순', '임민수'),
#   ('조경순', '김수창'),
#   ('조경순', '홍종국'),
#   ('조경순', '최근영'),
#   ('조경순', '김상원'),
#   ('조경순', '나유석'),
#   ('조경순', '신재범'),
#   ('조경순', '오익근'),
#   ('조경순', '강준규'),
#   ('조경순', '강윤기'),
#   ('조경순', '김성원'),
#   ('조경순', '박정환'),
#   ('조경순', '정기동'),
#   ('조경순', '이정훈'),
#   ('조경순', '김봉진'),
#   ('조경순', '박현식'),
#   ('조경순', '이성영'),
#   ('조경순', '김병철'),
#   ('조경순', '이창세'),
#   ('조경순', '조홍희'),
#   ('조경순', '김창수'),
#   ('조경순', '원윤희'),
#   ('조경순', '김범철'),
#   ('조경순', '송혁'),
#   ('조경순', '길기모'),
#   ('조경순', '박성준'),
#   ('조경순', '이정화'),
#   ('조경순', '권택현'),
#   ('조경순', '정연규'),
#   ('조경순', '김호중'),
#   ('조경순', '정연우'),
#   ('조경순', '이재우'),
#   ('조경순', '양홍석'),
#   ('조경순', '임민수'),
#   ('조경순', '김수창'),
#   ('조경순', '홍종국'),
#   ('조경순', '최근영'),
#   ('조경순', '김상원'),
#   ('조경순', '나유석'),
#   ('조경순', '신재범'),
#   ('조경순', '강준규'),
#   ('조경순', '강윤기'),
#   ('조경순', '김성원'),
#   ('조경순', '오익근'),
#   ('조경순', '박정환'),
#   ('조경순', '송종원'),
#   ('조경순', '김경렬'),
#   ('조경순', '김광혁'),
#   ('조경순', '박석원'),
#   ('조경순', '김성균'),
#   ('조경순', '최광철'),
#   ('조경순', '최대경'),
#   ('조경순', '이정훈'),
#   ('조경순', '김봉진'),
#   ('조경순', '김병철'),
#   ('조경순', '김상혁'),
#   ('조경순', '이성영'),
#   ('조경순', '정회민'),
#   ('조경순', '이창세'),
#   ('조경순', '김창수'),
#   ('조경순', '원윤희'),
#   ('조경순', '김성호'),
#   ('조경순', '김범철'),
#   ('홍대한', '이정화'),
#   ('홍대한', '진승욱'),
#   ('홍대한', '권택현'),
#   ('홍대한', '박성준'),
#   ('홍대한', '정연규'),
#   ('홍대한', '정재중'),
#   ('홍대한', '양홍석'),
#   ('홍대한', '김호중'),
#   ('홍대한', '문병식'),
#   ('홍대한', '정연우'),
#   ('홍대한', '임민수'),
#   ('홍대한', '김수창'),
#   ('홍대한', '이재우'),
#   ('홍대한', '홍종국'),
#   ('홍대한', '최근영'),
#   ('홍대한', '김상원'),
#   ('홍대한', '오익근'),
#   ('홍대한', '나유석'),
#   ('홍대한', '신재범'),
#   ('홍대한', '강준규'),
#   ('홍대한', '강윤기'),
#   ('홍대한', '김성원'),
#   ('홍대한', '정기동'),
#   ('홍대한', '박현식'),
#   ('홍대한', '이지원'),
#   ('홍대한', '김병철'),
#   ('홍대한', '이창세'),
#   ('홍대한', '조홍희'),
#   ('홍대한', '김범철'),
#   ('홍대한', '송혁'),
#   ('홍대한', '송혁'),
#   ('홍대한', '길기모'),
#   ('홍대한', '유창범'),
#   ('홍대한', '박성준'),
#   ('홍대한', '홍대한'),
#   ('홍대한', '이정화'),
#   ('홍대한', '진승욱'),
#   ('홍대한', '권택현'),
#   ('홍대한', '정연규'),
#   ('홍대한', '김호중'),
#   ('홍대한', '양홍석'),
#   ('홍대한', '정연우'),
#   ('홍대한', '이재우'),
#   ('홍대한', '임민수'),
#   ('홍대한', '김수창'),
#   ('홍대한', '홍종국'),
#   ('홍대한', '최근영'),
#   ('홍대한', '김상원'),
#   ('홍대한', '나유석'),
#   ('홍대한', '신재범'),
#   ('홍대한', '오익근'),
#   ('홍대한', '강준규'),
#   ('홍대한', '강윤기'),
#   ('홍대한', '김성원'),
#   ('홍대한', '박정환'),
#   ('홍대한', '정기동'),
#   ('홍대한', '이정훈'),
#   ('홍대한', '김봉진'),
#   ('홍대한', '박현식'),
#   ('홍대한', '이성영'),
#   ('홍대한', '김병철'),
#   ('홍대한', '이창세'),
#   ('홍대한', '조홍희'),
#   ('홍대한', '김창수'),
#   ('홍대한', '원윤희'),
#   ('홍대한', '김범철'),
#   ('홍대한', '송혁'),
#   ('홍대한', '길기모'),
#   ('홍대한', '박성준'),
#   ('홍대한', '이정화'),
#   ('홍대한', '권택현'),
#   ('홍대한', '정연규'),
#   ('홍대한', '김호중'),
#   ('홍대한', '정연우'),
#   ('홍대한', '이재우'),
#   ('홍대한', '양홍석'),
#   ('홍대한', '임민수'),
#   ('홍대한', '김수창'),
#   ('홍대한', '홍종국'),
#   ('홍대한', '최근영'),
#   ('홍대한', '김상원'),
#   ('홍대한', '나유석'),
#   ('홍대한', '신재범'),
#   ('홍대한', '강준규'),
#   ('홍대한', '강윤기'),
#   ('홍대한', '김성원'),
#   ('홍대한', '오익근'),
#   ('홍대한', '박정환'),
#   ('홍대한', '송종원'),
#   ('홍대한', '김경렬'),
#   ('홍대한', '김광혁'),
#   ('홍대한', '박석원'),
#   ('홍대한', '김성균'),
#   ('홍대한', '최광철'),
#   ('홍대한', '최대경'),
#   ('홍대한', '이정훈'),
#   ('홍대한', '김봉진'),
#   ('홍대한', '김병철'),
#   ('홍대한', '김상혁'),
#   ('홍대한', '이성영'),
#   ('홍대한', '정회민'),
#   ('홍대한', '이창세'),
#   ('홍대한', '김창수'),
#   ('홍대한', '원윤희'),
#   ('홍대한', '김성호'),
#   ('홍대한', '김범철'),
#   ('이정화', '진승욱'),
#   ('이정화', '권택현'),
#   ('이정화', '박성준'),
#   ('이정화', '정연규'),
#   ('이정화', '정재중'),
#   ('이정화', '양홍석'),
#   ('이정화', '김호중'),
#   ('이정화', '문병식'),
#   ('이정화', '정연우'),
#   ('이정화', '임민수'),
#   ('이정화', '김수창'),
#   ('이정화', '이재우'),
#   ('이정화', '홍종국'),
#   ('이정화', '최근영'),
#   ('이정화', '김상원'),
#   ('이정화', '오익근'),
#   ('이정화', '나유석'),
#   ('이정화', '신재범'),
#   ('이정화', '강준규'),
#   ('이정화', '강윤기'),
#   ('이정화', '김성원'),
#   ('이정화', '정기동'),
#   ('이정화', '박현식'),
#   ('이정화', '이지원'),
#   ('이정화', '김병철'),
#   ('이정화', '이창세'),
#   ('이정화', '조홍희'),
#   ('이정화', '김범철'),
#   ('이정화', '송혁'),
#   ('이정화', '송혁'),
#   ('이정화', '길기모'),
#   ('이정화', '유창범'),
#   ('이정화', '박성준'),
#   ('이정화', '홍대한'),
#   ('이정화', '이정화'),
#   ('이정화', '진승욱'),
#   ('이정화', '권택현'),
#   ('이정화', '정연규'),
#   ('이정화', '김호중'),
#   ('이정화', '양홍석'),
#   ('이정화', '정연우'),
#   ('이정화', '이재우'),
#   ('이정화', '임민수'),
#   ('이정화', '김수창'),
#   ('이정화', '홍종국'),
#   ('이정화', '최근영'),
#   ('이정화', '김상원'),
#   ('이정화', '나유석'),
#   ('이정화', '신재범'),
#   ('이정화', '오익근'),
#   ('이정화', '강준규'),
#   ('이정화', '강윤기'),
#   ('이정화', '김성원'),
#   ('이정화', '박정환'),
#   ('이정화', '정기동'),
#   ('이정화', '이정훈'),
#   ('이정화', '김봉진'),
#   ('이정화', '박현식'),
#   ('이정화', '이성영'),
#   ('이정화', '김병철'),
#   ('이정화', '이창세'),
#   ('이정화', '조홍희'),
#   ('이정화', '김창수'),
#   ('이정화', '원윤희'),
#   ('이정화', '김범철'),
#   ('이정화', '송혁'),
#   ('이정화', '길기모'),
#   ('이정화', '박성준'),
#   ('이정화', '이정화'),
#   ('이정화', '권택현'),
#   ('이정화', '정연규'),
#   ('이정화', '김호중'),
#   ('이정화', '정연우'),
#   ('이정화', '이재우'),
#   ('이정화', '양홍석'),
#   ('이정화', '임민수'),
#   ('이정화', '김수창'),
#   ('이정화', '홍종국'),
#   ('이정화', '최근영'),
#   ('이정화', '김상원'),
#   ('이정화', '나유석'),
#   ('이정화', '신재범'),
#   ('이정화', '강준규'),
#   ('이정화', '강윤기'),
#   ('이정화', '김성원'),
#   ('이정화', '오익근'),
#   ('이정화', '박정환'),
#   ('이정화', '송종원'),
#   ('이정화', '김경렬'),
#   ('이정화', '김광혁'),
#   ('이정화', '박석원'),
#   ('이정화', '김성균'),
#   ('이정화', '최광철'),
#   ('이정화', '최대경'),
#   ('이정화', '이정훈'),
#   ('이정화', '김봉진'),
#   ('이정화', '김병철'),
#   ('이정화', '김상혁'),
#   ('이정화', '이성영'),
#   ('이정화', '정회민'),
#   ('이정화', '이창세'),
#   ('이정화', '김창수'),
#   ('이정화', '원윤희'),
#   ('이정화', '김성호'),
#   ('이정화', '김범철'),
#   ('진승욱', '권택현'),
#   ('진승욱', '박성준'),
#   ('진승욱', '정연규'),
#   ('진승욱', '정재중'),
#   ('진승욱', '양홍석'),
#   ('진승욱', '김호중'),
#   ('진승욱', '문병식'),
#   ('진승욱', '정연우'),
#   ('진승욱', '임민수'),
#   ('진승욱', '김수창'),
#   ('진승욱', '이재우'),
#   ('진승욱', '홍종국'),
#   ('진승욱', '최근영'),
#   ('진승욱', '김상원'),
#   ('진승욱', '오익근'),
#   ('진승욱', '나유석'),
#   ('진승욱', '신재범'),
#   ('진승욱', '강준규'),
#   ('진승욱', '강윤기'),
#   ('진승욱', '김성원'),
#   ('진승욱', '정기동'),
#   ('진승욱', '박현식'),
#   ('진승욱', '이지원'),
#   ('진승욱', '김병철'),
#   ('진승욱', '이창세'),
#   ('진승욱', '조홍희'),
#   ('진승욱', '김범철'),
#   ('진승욱', '송혁'),
#   ('진승욱', '송혁'),
#   ('진승욱', '길기모'),
#   ('진승욱', '유창범'),
#   ('진승욱', '박성준'),
#   ('진승욱', '홍대한'),
#   ('진승욱', '이정화'),
#   ('진승욱', '진승욱'),
#   ('진승욱', '권택현'),
#   ('진승욱', '정연규'),
#   ('진승욱', '김호중'),
#   ('진승욱', '양홍석'),
#   ('진승욱', '정연우'),
#   ('진승욱', '이재우'),
#   ('진승욱', '임민수'),
#   ('진승욱', '김수창'),
#   ('진승욱', '홍종국'),
#   ('진승욱', '최근영'),
#   ('진승욱', '김상원'),
#   ('진승욱', '나유석'),
#   ('진승욱', '신재범'),
#   ('진승욱', '오익근'),
#   ('진승욱', '강준규'),
#   ('진승욱', '강윤기'),
#   ('진승욱', '김성원'),
#   ('진승욱', '박정환'),
#   ('진승욱', '정기동'),
#   ('진승욱', '이정훈'),
#   ('진승욱', '김봉진'),
#   ('진승욱', '박현식'),
#   ('진승욱', '이성영'),
#   ('진승욱', '김병철'),
#   ('진승욱', '이창세'),
#   ('진승욱', '조홍희'),
#   ('진승욱', '김창수'),
#   ('진승욱', '원윤희'),
#   ('진승욱', '김범철'),
#   ('진승욱', '송혁'),
#   ('진승욱', '길기모'),
#   ('진승욱', '박성준'),
#   ('진승욱', '이정화'),
#   ('진승욱', '권택현'),
#   ('진승욱', '정연규'),
#   ('진승욱', '김호중'),
#   ('진승욱', '정연우'),
#   ('진승욱', '이재우'),
#   ('진승욱', '양홍석'),
#   ('진승욱', '임민수'),
#   ('진승욱', '김수창'),
#   ('진승욱', '홍종국'),
#   ('진승욱', '최근영'),
#   ('진승욱', '김상원'),
#   ('진승욱', '나유석'),
#   ('진승욱', '신재범'),
#   ('진승욱', '강준규'),
#   ('진승욱', '강윤기'),
#   ('진승욱', '김성원'),
#   ('진승욱', '오익근'),
#   ('진승욱', '박정환'),
#   ('진승욱', '송종원'),
#   ('진승욱', '김경렬'),
#   ('진승욱', '김광혁'),
#   ('진승욱', '박석원'),
#   ('진승욱', '김성균'),
#   ('진승욱', '최광철'),
#   ('진승욱', '최대경'),
#   ('진승욱', '이정훈'),
#   ('진승욱', '김봉진'),
#   ('진승욱', '김병철'),
#   ('진승욱', '김상혁'),
#   ('진승욱', '이성영'),
#   ('진승욱', '정회민'),
#   ('진승욱', '이창세'),
#   ('진승욱', '김창수'),
#   ('진승욱', '원윤희'),
#   ('진승욱', '김성호'),
#   ('진승욱', '김범철'),
#   ('권택현', '박성준'),
#   ('권택현', '정연규'),
#   ('권택현', '정재중'),
#   ('권택현', '양홍석'),
#   ('권택현', '김호중'),
#   ('권택현', '문병식'),
#   ('권택현', '정연우'),
#   ('권택현', '임민수'),
#   ('권택현', '김수창'),
#   ('권택현', '이재우'),
#   ('권택현', '홍종국'),
#   ('권택현', '최근영'),
#   ('권택현', '김상원'),
#   ('권택현', '오익근'),
#   ('권택현', '나유석'),
#   ('권택현', '신재범'),
#   ('권택현', '강준규'),
#   ('권택현', '강윤기'),
#   ('권택현', '김성원'),
#   ('권택현', '정기동'),
#   ('권택현', '박현식'),
#   ('권택현', '이지원'),
#   ('권택현', '김병철'),
#   ('권택현', '이창세'),
#   ('권택현', '조홍희'),
#   ('권택현', '김범철'),
#   ('권택현', '송혁'),
#   ('권택현', '송혁'),
#   ('권택현', '길기모'),
#   ('권택현', '유창범'),
#   ('권택현', '박성준'),
#   ('권택현', '홍대한'),
#   ('권택현', '이정화'),
#   ('권택현', '진승욱'),
#   ('권택현', '권택현'),
#   ('권택현', '정연규'),
#   ('권택현', '김호중'),
#   ('권택현', '양홍석'),
#   ('권택현', '정연우'),
#   ('권택현', '이재우'),
#   ('권택현', '임민수'),
#   ('권택현', '김수창'),
#   ('권택현', '홍종국'),
#   ('권택현', '최근영'),
#   ('권택현', '김상원'),
#   ('권택현', '나유석'),
#   ('권택현', '신재범'),
#   ('권택현', '오익근'),
#   ('권택현', '강준규'),
#   ('권택현', '강윤기'),
#   ('권택현', '김성원'),
#   ('권택현', '박정환'),
#   ('권택현', '정기동'),
#   ('권택현', '이정훈'),
#   ('권택현', '김봉진'),
#   ('권택현', '박현식'),
#   ('권택현', '이성영'),
#   ('권택현', '김병철'),
#   ('권택현', '이창세'),
#   ('권택현', '조홍희'),
#   ('권택현', '김창수'),
#   ('권택현', '원윤희'),
#   ('권택현', '김범철'),
#   ('권택현', '송혁'),
#   ('권택현', '길기모'),
#   ('권택현', '박성준'),
#   ('권택현', '이정화'),
#   ('권택현', '권택현'),
#   ('권택현', '정연규'),
#   ('권택현', '김호중'),
#   ('권택현', '정연우'),
#   ('권택현', '이재우'),
#   ('권택현', '양홍석'),
#   ('권택현', '임민수'),
#   ('권택현', '김수창'),
#   ('권택현', '홍종국'),
#   ('권택현', '최근영'),
#   ('권택현', '김상원'),
#   ('권택현', '나유석'),
#   ('권택현', '신재범'),
#   ('권택현', '강준규'),
#   ('권택현', '강윤기'),
#   ('권택현', '김성원'),
#   ('권택현', '오익근'),
#   ('권택현', '박정환'),
#   ('권택현', '송종원'),
#   ('권택현', '김경렬'),
#   ('권택현', '김광혁'),
#   ('권택현', '박석원'),
#   ('권택현', '김성균'),
#   ('권택현', '최광철'),
#   ('권택현', '최대경'),
#   ('권택현', '이정훈'),
#   ('권택현', '김봉진'),
#   ('권택현', '김병철'),
#   ('권택현', '김상혁'),
#   ('권택현', '이성영'),
#   ('권택현', '정회민'),
#   ('권택현', '이창세'),
#   ('권택현', '김창수'),
#   ('권택현', '원윤희'),
#   ('권택현', '김성호'),
#   ('권택현', '김범철'),
#   ('박성준', '정연규'),
#   ('박성준', '정재중'),
#   ('박성준', '양홍석'),
#   ('박성준', '김호중'),
#   ('박성준', '문병식'),
#   ('박성준', '정연우'),
#   ('박성준', '임민수'),
#   ('박성준', '김수창'),
#   ('박성준', '이재우'),
#   ('박성준', '홍종국'),
#   ('박성준', '최근영'),
#   ('박성준', '김상원'),
#   ('박성준', '오익근'),
#   ('박성준', '나유석'),
#   ('박성준', '신재범'),
#   ('박성준', '강준규'),
#   ('박성준', '강윤기'),
#   ('박성준', '김성원'),
#   ('박성준', '정기동'),
#   ('박성준', '박현식'),
#   ('박성준', '이지원'),
#   ('박성준', '김병철'),
#   ('박성준', '이창세'),
#   ('박성준', '조홍희'),
#   ('박성준', '김범철'),
#   ('박성준', '송혁'),
#   ('박성준', '송혁'),
#   ('박성준', '길기모'),
#   ('박성준', '유창범'),
#   ('박성준', '박성준'),
#   ('박성준', '홍대한'),
#   ('박성준', '이정화'),
#   ('박성준', '진승욱'),
#   ('박성준', '권택현'),
#   ('박성준', '정연규'),
#   ('박성준', '김호중'),
#   ('박성준', '양홍석'),
#   ('박성준', '정연우'),
#   ('박성준', '이재우'),
#   ('박성준', '임민수'),
#   ('박성준', '김수창'),
#   ('박성준', '홍종국'),
#   ('박성준', '최근영'),
#   ('박성준', '김상원'),
#   ('박성준', '나유석'),
#   ('박성준', '신재범'),
#   ('박성준', '오익근'),
#   ('박성준', '강준규'),
#   ('박성준', '강윤기'),
#   ('박성준', '김성원'),
#   ('박성준', '박정환'),
#   ('박성준', '정기동'),
#   ('박성준', '이정훈'),
#   ('박성준', '김봉진'),
#   ('박성준', '박현식'),
#   ('박성준', '이성영'),
#   ('박성준', '김병철'),
#   ('박성준', '이창세'),
#   ('박성준', '조홍희'),
#   ('박성준', '김창수'),
#   ('박성준', '원윤희'),
#   ('박성준', '김범철'),
#   ('박성준', '송혁'),
#   ('박성준', '길기모'),
#   ('박성준', '박성준'),
#   ('박성준', '이정화'),
#   ('박성준', '권택현'),
#   ('박성준', '정연규'),
#   ('박성준', '김호중'),
#   ('박성준', '정연우'),
#   ('박성준', '이재우'),
#   ('박성준', '양홍석'),
#   ('박성준', '임민수'),
#   ('박성준', '김수창'),
#   ('박성준', '홍종국'),
#   ('박성준', '최근영'),
#   ('박성준', '김상원'),
#   ('박성준', '나유석'),
#   ('박성준', '신재범'),
#   ('박성준', '강준규'),
#   ('박성준', '강윤기'),
#   ('박성준', '김성원'),
#   ('박성준', '오익근'),
#   ('박성준', '박정환'),
#   ('박성준', '송종원'),
#   ('박성준', '김경렬'),
#   ('박성준', '김광혁'),
#   ('박성준', '박석원'),
#   ('박성준', '김성균'),
#   ('박성준', '최광철'),
#   ('박성준', '최대경'),
#   ('박성준', '이정훈'),
#   ('박성준', '김봉진'),
#   ('박성준', '김병철'),
#   ('박성준', '김상혁'),
#   ('박성준', '이성영'),
#   ('박성준', '정회민'),
#   ('박성준', '이창세'),
#   ('박성준', '김창수'),
#   ('박성준', '원윤희'),
#   ('박성준', '김성호'),
#   ('박성준', '김범철'),
#   ('정연규', '정재중'),
#   ('정연규', '양홍석'),
#   ('정연규', '김호중'),
#   ('정연규', '문병식'),
#   ('정연규', '정연우'),
#   ('정연규', '임민수'),
#   ('정연규', '김수창'),
#   ('정연규', '이재우'),
#   ('정연규', '홍종국'),
#   ('정연규', '최근영'),
#   ('정연규', '김상원'),
#   ('정연규', '오익근'),
#   ('정연규', '나유석'),
#   ('정연규', '신재범'),
#   ('정연규', '강준규'),
#   ('정연규', '강윤기'),
#   ('정연규', '김성원'),
#   ('정연규', '정기동'),
#   ('정연규', '박현식'),
#   ('정연규', '이지원'),
#   ('정연규', '김병철'),
#   ('정연규', '이창세'),
#   ('정연규', '조홍희'),
#   ('정연규', '김범철'),
#   ('정연규', '송혁'),
#   ('정연규', '송혁'),
#   ('정연규', '길기모'),
#   ('정연규', '유창범'),
#   ('정연규', '박성준'),
#   ('정연규', '홍대한'),
#   ('정연규', '이정화'),
#   ('정연규', '진승욱'),
#   ('정연규', '권택현'),
#   ('정연규', '정연규'),
#   ('정연규', '김호중'),
#   ('정연규', '양홍석'),
#   ('정연규', '정연우'),
#   ('정연규', '이재우'),
#   ('정연규', '임민수'),
#   ('정연규', '김수창'),
#   ('정연규', '홍종국'),
#   ('정연규', '최근영'),
#   ('정연규', '김상원'),
#   ('정연규', '나유석'),
#   ('정연규', '신재범'),
#   ('정연규', '오익근'),
#   ('정연규', '강준규'),
#   ('정연규', '강윤기'),
#   ('정연규', '김성원'),
#   ('정연규', '박정환'),
#   ('정연규', '정기동'),
#   ('정연규', '이정훈'),
#   ('정연규', '김봉진'),
#   ('정연규', '박현식'),
#   ('정연규', '이성영'),
#   ('정연규', '김병철'),
#   ('정연규', '이창세'),
#   ('정연규', '조홍희'),
#   ('정연규', '김창수'),
#   ('정연규', '원윤희'),
#   ('정연규', '김범철'),
#   ('정연규', '송혁'),
#   ('정연규', '길기모'),
#   ('정연규', '박성준'),
#   ('정연규', '이정화'),
#   ('정연규', '권택현'),
#   ('정연규', '정연규'),
#   ('정연규', '김호중'),
#   ('정연규', '정연우'),
#   ('정연규', '이재우'),
#   ('정연규', '양홍석'),
#   ('정연규', '임민수'),
#   ('정연규', '김수창'),
#   ('정연규', '홍종국'),
#   ('정연규', '최근영'),
#   ('정연규', '김상원'),
#   ('정연규', '나유석'),
#   ('정연규', '신재범'),
#   ('정연규', '강준규'),
#   ('정연규', '강윤기'),
#   ('정연규', '김성원'),
#   ('정연규', '오익근'),
#   ('정연규', '박정환'),
#   ('정연규', '송종원'),
#   ('정연규', '김경렬'),
#   ('정연규', '김광혁'),
#   ('정연규', '박석원'),
#   ('정연규', '김성균'),
#   ('정연규', '최광철'),
#   ('정연규', '최대경'),
#   ('정연규', '이정훈'),
#   ('정연규', '김봉진'),
#   ('정연규', '김병철'),
#   ('정연규', '김상혁'),
#   ('정연규', '이성영'),
#   ('정연규', '정회민'),
#   ('정연규', '이창세'),
#   ('정연규', '김창수'),
#   ('정연규', '원윤희'),
#   ('정연규', '김성호'),
#   ('정연규', '김범철'),
#   ('정재중', '양홍석'),
#   ('정재중', '김호중'),
#   ('정재중', '문병식'),
#   ('정재중', '정연우'),
#   ('정재중', '임민수'),
#   ('정재중', '김수창'),
#   ('정재중', '이재우'),
#   ('정재중', '홍종국'),
#   ('정재중', '최근영'),
#   ('정재중', '김상원'),
#   ('정재중', '오익근'),
#   ('정재중', '나유석'),
#   ('정재중', '신재범'),
#   ('정재중', '강준규'),
#   ('정재중', '강윤기'),
#   ('정재중', '김성원'),
#   ('정재중', '정기동'),
#   ('정재중', '박현식'),
#   ('정재중', '이지원'),
#   ('정재중', '김병철'),
#   ('정재중', '이창세'),
#   ('정재중', '조홍희'),
#   ('정재중', '김범철'),
#   ('정재중', '송혁'),
#   ('정재중', '송혁'),
#   ('정재중', '길기모'),
#   ('정재중', '유창범'),
#   ('정재중', '박성준'),
#   ('정재중', '홍대한'),
#   ('정재중', '이정화'),
#   ('정재중', '진승욱'),
#   ('정재중', '권택현'),
#   ('정재중', '정연규'),
#   ('정재중', '김호중'),
#   ('정재중', '양홍석'),
#   ('정재중', '정연우'),
#   ('정재중', '이재우'),
#   ('정재중', '임민수'),
#   ('정재중', '김수창'),
#   ('정재중', '홍종국'),
#   ('정재중', '최근영'),
#   ('정재중', '김상원'),
#   ('정재중', '나유석'),
#   ('정재중', '신재범'),
#   ('정재중', '오익근'),
#   ('정재중', '강준규'),
#   ('정재중', '강윤기'),
#   ('정재중', '김성원'),
#   ('정재중', '박정환'),
#   ('정재중', '정기동'),
#   ('정재중', '이정훈'),
#   ('정재중', '김봉진'),
#   ('정재중', '박현식'),
#   ('정재중', '이성영'),
#   ('정재중', '김병철'),
#   ...]]

# %%
network_df
# Out:
#      source target
# 0       신인식    길기모
# 1       신인식    조경순
# 2       신인식    홍대한
# 3       신인식    이정화
# 4       신인식    진승욱
# ...     ...    ...
# 5990    김창수    김성호
# 5991    김창수    김범철
# 5992    원윤희    김성호
# 5993    원윤희    김범철
# 5994    김성호    김범철
#
# [5995 rows x 2 columns]

# %%
col_name = ['source', 'target']
for i in sex_2:
    network_df.append(pd.DataFrame(i, columns=col_name))
# Out:
# /var/folders/zz/lgz2xn5d2js431w926kk85pm0000gp/T/ipykernel_97093/2549910138.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   network_df.append(pd.DataFrame(i, columns=col_name))
# /var/folders/zz/lgz2xn5d2js431w926kk85pm0000gp/T/ipykernel_97093/2549910138.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   network_df.append(pd.DataFrame(i, columns=col_name))

# %%
network_df
# Out:
#      source target
# 0       신인식    길기모
# 1       신인식    조경순
# 2       신인식    홍대한
# 3       신인식    이정화
# 4       신인식    진승욱
# ...     ...    ...
# 5990    김창수    김성호
# 5991    김창수    김범철
# 5992    원윤희    김성호
# 5993    원윤희    김범철
# 5994    김성호    김범철
#
# [5995 rows x 2 columns]

# %%
network_df['weight'] = network_df.groupby(['source', 'target'])['source'].transform('size')
network_df = network_df.dropna()

G = nx.from_pandas_edgelist(network_df, 'source', 'target',
                            create_using=nx.DiGraph(), edge_attr='weight')

network_df
# Out:
#      source target  weight
# 0       신인식    길기모       3
# 1       신인식    조경순       1
# 2       신인식    홍대한       2
# 3       신인식    이정화       3
# 4       신인식    진승욱       2
# ...     ...    ...     ...
# 5990    김창수    김성호       2
# 5991    김창수    김범철       3
# 5992    원윤희    김성호       2
# 5993    원윤희    김범철       3
# 5994    김성호    김범철       1
#
# [5995 rows x 3 columns]

# %%
from pyvis.network import Network

net = Network(notebook=True)
net.from_nx(G)
net.show_buttons(filter_=['nodes'])
net.show('example3.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# example3.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="example3.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
def make_df(network_df,col_name):
    for i in col_name:
        df=pd.DataFrame(i, columns=col_name)
        pd.concat([network_df,df],ignore_index = True)

# %%
network_df=make_df(network_df,position_2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 network_df=make_df(network_df,position_2)
#
# Input In [40], in make_df(network_df, col_name)
#       1 def make_df(network_df,col_name):
#       2     for i in col_name:
# ----> 3         df=pd.DataFrame(i, columns=col_name)
#       4         pd.concat([network_df,df],ignore_index = True)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:720, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     714 if not isinstance(data, np.ndarray) and treat_as_nested(data):
#     715     # exclude ndarray as we may have cast it a few lines above
#     716     if columns is not None:
#     717         # error: Argument 1 to "ensure_index" has incompatible type
#     718         # "Collection[Any]"; expected "Union[Union[Union[ExtensionArray,
#     719         # ndarray], Index, Series], Sequence[Any]]"
# --> 720         columns = ensure_index(columns)  # type: ignore[arg-type]
#     721     arrays, columns, index = nested_data_to_arrays(
#     722         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     723         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#    (...)
#     727         dtype,
#     728     )
#     729     mgr = arrays_to_mgr(
#     730         arrays,
#     731         columns,
#    (...)
#     734         typ=manager,
#     735     )
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:7039, in ensure_index(index_like, copy)
#    7036 if len(index_like) and lib.is_all_arraylike(index_like):
#    7037     from pandas.core.indexes.multi import MultiIndex
# -> 7039     return MultiIndex.from_arrays(index_like)
#    7040 else:
#    7041     return Index._with_infer(index_like, copy=copy, tupleize_cols=False)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/multi.py:487, in MultiIndex.from_arrays(cls, arrays, sortorder, names)
#     485 for i in range(1, len(arrays)):
#     486     if len(arrays[i]) != len(arrays[i - 1]):
# --> 487         raise ValueError("all arrays must be same length")
#     489 codes, levels = factorize_from_iterables(arrays)
#     490 if names is lib.no_default:
#
# ValueError: all arrays must be same length

# %%
position_2 = list(filter(None, position_2))

# %%
position_2
# Out:
# [[('이어룡', '이어룡'), ('이어룡', '이어룡'), ('이어룡', '이어룡')],
#  [('신인식', '길기모'),
#   ('신인식', '조경순'),
#   ('신인식', '홍대한'),
#   ('신인식', '이정화'),
#   ('신인식', '진승욱'),
#   ('신인식', '권택현'),
#   ('신인식', '박성준'),
#   ('신인식', '정연규'),
#   ('신인식', '길기모'),
#   ('신인식', '유창범'),
#   ('신인식', '박성준'),
#   ('신인식', '홍대한'),
#   ('신인식', '이정화'),
#   ('신인식', '진승욱'),
#   ('신인식', '권택현'),
#   ('신인식', '정연규'),
#   ('신인식', '김호중'),
#   ('신인식', '정연우'),
#   ('신인식', '이재우'),
#   ('신인식', '길기모'),
#   ('신인식', '박성준'),
#   ('신인식', '이정화'),
#   ('신인식', '권택현'),
#   ('신인식', '정연규'),
#   ('신인식', '김호중'),
#   ('신인식', '정연우'),
#   ('신인식', '이재우'),
#   ('길기모', '조경순'),
#   ('길기모', '홍대한'),
#   ('길기모', '이정화'),
#   ('길기모', '진승욱'),
#   ('길기모', '권택현'),
#   ('길기모', '박성준'),
#   ('길기모', '정연규'),
#   ('길기모', '길기모'),
#   ('길기모', '유창범'),
#   ('길기모', '박성준'),
#   ('길기모', '홍대한'),
#   ('길기모', '이정화'),
#   ('길기모', '진승욱'),
#   ('길기모', '권택현'),
#   ('길기모', '정연규'),
#   ('길기모', '김호중'),
#   ('길기모', '정연우'),
#   ('길기모', '이재우'),
#   ('길기모', '길기모'),
#   ('길기모', '박성준'),
#   ('길기모', '이정화'),
#   ('길기모', '권택현'),
#   ('길기모', '정연규'),
#   ('길기모', '김호중'),
#   ('길기모', '정연우'),
#   ('길기모', '이재우'),
#   ('조경순', '홍대한'),
#   ('조경순', '이정화'),
#   ('조경순', '진승욱'),
#   ('조경순', '권택현'),
#   ('조경순', '박성준'),
#   ('조경순', '정연규'),
#   ('조경순', '길기모'),
#   ('조경순', '유창범'),
#   ('조경순', '박성준'),
#   ('조경순', '홍대한'),
#   ('조경순', '이정화'),
#   ('조경순', '진승욱'),
#   ('조경순', '권택현'),
#   ('조경순', '정연규'),
#   ('조경순', '김호중'),
#   ('조경순', '정연우'),
#   ('조경순', '이재우'),
#   ('조경순', '길기모'),
#   ('조경순', '박성준'),
#   ('조경순', '이정화'),
#   ('조경순', '권택현'),
#   ('조경순', '정연규'),
#   ('조경순', '김호중'),
#   ('조경순', '정연우'),
#   ('조경순', '이재우'),
#   ('홍대한', '이정화'),
#   ('홍대한', '진승욱'),
#   ('홍대한', '권택현'),
#   ('홍대한', '박성준'),
#   ('홍대한', '정연규'),
#   ('홍대한', '길기모'),
#   ('홍대한', '유창범'),
#   ('홍대한', '박성준'),
#   ('홍대한', '홍대한'),
#   ('홍대한', '이정화'),
#   ('홍대한', '진승욱'),
#   ('홍대한', '권택현'),
#   ('홍대한', '정연규'),
#   ('홍대한', '김호중'),
#   ('홍대한', '정연우'),
#   ('홍대한', '이재우'),
#   ('홍대한', '길기모'),
#   ('홍대한', '박성준'),
#   ('홍대한', '이정화'),
#   ('홍대한', '권택현'),
#   ('홍대한', '정연규'),
#   ('홍대한', '김호중'),
#   ('홍대한', '정연우'),
#   ('홍대한', '이재우'),
#   ('이정화', '진승욱'),
#   ('이정화', '권택현'),
#   ('이정화', '박성준'),
#   ('이정화', '정연규'),
#   ('이정화', '길기모'),
#   ('이정화', '유창범'),
#   ('이정화', '박성준'),
#   ('이정화', '홍대한'),
#   ('이정화', '이정화'),
#   ('이정화', '진승욱'),
#   ('이정화', '권택현'),
#   ('이정화', '정연규'),
#   ('이정화', '김호중'),
#   ('이정화', '정연우'),
#   ('이정화', '이재우'),
#   ('이정화', '길기모'),
#   ('이정화', '박성준'),
#   ('이정화', '이정화'),
#   ('이정화', '권택현'),
#   ('이정화', '정연규'),
#   ('이정화', '김호중'),
#   ('이정화', '정연우'),
#   ('이정화', '이재우'),
#   ('진승욱', '권택현'),
#   ('진승욱', '박성준'),
#   ('진승욱', '정연규'),
#   ('진승욱', '길기모'),
#   ('진승욱', '유창범'),
#   ('진승욱', '박성준'),
#   ('진승욱', '홍대한'),
#   ('진승욱', '이정화'),
#   ('진승욱', '진승욱'),
#   ('진승욱', '권택현'),
#   ('진승욱', '정연규'),
#   ('진승욱', '김호중'),
#   ('진승욱', '정연우'),
#   ('진승욱', '이재우'),
#   ('진승욱', '길기모'),
#   ('진승욱', '박성준'),
#   ('진승욱', '이정화'),
#   ('진승욱', '권택현'),
#   ('진승욱', '정연규'),
#   ('진승욱', '김호중'),
#   ('진승욱', '정연우'),
#   ('진승욱', '이재우'),
#   ('권택현', '박성준'),
#   ('권택현', '정연규'),
#   ('권택현', '길기모'),
#   ('권택현', '유창범'),
#   ('권택현', '박성준'),
#   ('권택현', '홍대한'),
#   ('권택현', '이정화'),
#   ('권택현', '진승욱'),
#   ('권택현', '권택현'),
#   ('권택현', '정연규'),
#   ('권택현', '김호중'),
#   ('권택현', '정연우'),
#   ('권택현', '이재우'),
#   ('권택현', '길기모'),
#   ('권택현', '박성준'),
#   ('권택현', '이정화'),
#   ('권택현', '권택현'),
#   ('권택현', '정연규'),
#   ('권택현', '김호중'),
#   ('권택현', '정연우'),
#   ('권택현', '이재우'),
#   ('박성준', '정연규'),
#   ('박성준', '길기모'),
#   ('박성준', '유창범'),
#   ('박성준', '박성준'),
#   ('박성준', '홍대한'),
#   ('박성준', '이정화'),
#   ('박성준', '진승욱'),
#   ('박성준', '권택현'),
#   ('박성준', '정연규'),
#   ('박성준', '김호중'),
#   ('박성준', '정연우'),
#   ('박성준', '이재우'),
#   ('박성준', '길기모'),
#   ('박성준', '박성준'),
#   ('박성준', '이정화'),
#   ('박성준', '권택현'),
#   ('박성준', '정연규'),
#   ('박성준', '김호중'),
#   ('박성준', '정연우'),
#   ('박성준', '이재우'),
#   ('정연규', '길기모'),
#   ('정연규', '유창범'),
#   ('정연규', '박성준'),
#   ('정연규', '홍대한'),
#   ('정연규', '이정화'),
#   ('정연규', '진승욱'),
#   ('정연규', '권택현'),
#   ('정연규', '정연규'),
#   ('정연규', '김호중'),
#   ('정연규', '정연우'),
#   ('정연규', '이재우'),
#   ('정연규', '길기모'),
#   ('정연규', '박성준'),
#   ('정연규', '이정화'),
#   ('정연규', '권택현'),
#   ('정연규', '정연규'),
#   ('정연규', '김호중'),
#   ('정연규', '정연우'),
#   ('정연규', '이재우'),
#   ('길기모', '유창범'),
#   ('길기모', '박성준'),
#   ('길기모', '홍대한'),
#   ('길기모', '이정화'),
#   ('길기모', '진승욱'),
#   ('길기모', '권택현'),
#   ('길기모', '정연규'),
#   ('길기모', '김호중'),
#   ('길기모', '정연우'),
#   ('길기모', '이재우'),
#   ('길기모', '길기모'),
#   ('길기모', '박성준'),
#   ('길기모', '이정화'),
#   ('길기모', '권택현'),
#   ('길기모', '정연규'),
#   ('길기모', '김호중'),
#   ('길기모', '정연우'),
#   ('길기모', '이재우'),
#   ('유창범', '박성준'),
#   ('유창범', '홍대한'),
#   ('유창범', '이정화'),
#   ('유창범', '진승욱'),
#   ('유창범', '권택현'),
#   ('유창범', '정연규'),
#   ('유창범', '김호중'),
#   ('유창범', '정연우'),
#   ('유창범', '이재우'),
#   ('유창범', '길기모'),
#   ('유창범', '박성준'),
#   ('유창범', '이정화'),
#   ('유창범', '권택현'),
#   ('유창범', '정연규'),
#   ('유창범', '김호중'),
#   ('유창범', '정연우'),
#   ('유창범', '이재우'),
#   ('박성준', '홍대한'),
#   ('박성준', '이정화'),
#   ('박성준', '진승욱'),
#   ('박성준', '권택현'),
#   ('박성준', '정연규'),
#   ('박성준', '김호중'),
#   ('박성준', '정연우'),
#   ('박성준', '이재우'),
#   ('박성준', '길기모'),
#   ('박성준', '박성준'),
#   ('박성준', '이정화'),
#   ('박성준', '권택현'),
#   ('박성준', '정연규'),
#   ('박성준', '김호중'),
#   ('박성준', '정연우'),
#   ('박성준', '이재우'),
#   ('홍대한', '이정화'),
#   ('홍대한', '진승욱'),
#   ('홍대한', '권택현'),
#   ('홍대한', '정연규'),
#   ('홍대한', '김호중'),
#   ('홍대한', '정연우'),
#   ('홍대한', '이재우'),
#   ('홍대한', '길기모'),
#   ('홍대한', '박성준'),
#   ('홍대한', '이정화'),
#   ('홍대한', '권택현'),
#   ('홍대한', '정연규'),
#   ('홍대한', '김호중'),
#   ('홍대한', '정연우'),
#   ('홍대한', '이재우'),
#   ('이정화', '진승욱'),
#   ('이정화', '권택현'),
#   ('이정화', '정연규'),
#   ('이정화', '김호중'),
#   ('이정화', '정연우'),
#   ('이정화', '이재우'),
#   ('이정화', '길기모'),
#   ('이정화', '박성준'),
#   ('이정화', '이정화'),
#   ('이정화', '권택현'),
#   ('이정화', '정연규'),
#   ('이정화', '김호중'),
#   ('이정화', '정연우'),
#   ('이정화', '이재우'),
#   ('진승욱', '권택현'),
#   ('진승욱', '정연규'),
#   ('진승욱', '김호중'),
#   ('진승욱', '정연우'),
#   ('진승욱', '이재우'),
#   ('진승욱', '길기모'),
#   ('진승욱', '박성준'),
#   ('진승욱', '이정화'),
#   ('진승욱', '권택현'),
#   ('진승욱', '정연규'),
#   ('진승욱', '김호중'),
#   ('진승욱', '정연우'),
#   ('진승욱', '이재우'),
#   ('권택현', '정연규'),
#   ('권택현', '김호중'),
#   ('권택현', '정연우'),
#   ('권택현', '이재우'),
#   ('권택현', '길기모'),
#   ('권택현', '박성준'),
#   ('권택현', '이정화'),
#   ('권택현', '권택현'),
#   ('권택현', '정연규'),
#   ('권택현', '김호중'),
#   ('권택현', '정연우'),
#   ('권택현', '이재우'),
#   ('정연규', '김호중'),
#   ('정연규', '정연우'),
#   ('정연규', '이재우'),
#   ('정연규', '길기모'),
#   ('정연규', '박성준'),
#   ('정연규', '이정화'),
#   ('정연규', '권택현'),
#   ('정연규', '정연규'),
#   ('정연규', '김호중'),
#   ('정연규', '정연우'),
#   ('정연규', '이재우'),
#   ('김호중', '정연우'),
#   ('김호중', '이재우'),
#   ('김호중', '길기모'),
#   ('김호중', '박성준'),
#   ('김호중', '이정화'),
#   ('김호중', '권택현'),
#   ('김호중', '정연규'),
#   ('김호중', '김호중'),
#   ('김호중', '정연우'),
#   ('김호중', '이재우'),
#   ('정연우', '이재우'),
#   ('정연우', '길기모'),
#   ('정연우', '박성준'),
#   ('정연우', '이정화'),
#   ('정연우', '권택현'),
#   ('정연우', '정연규'),
#   ('정연우', '김호중'),
#   ('정연우', '정연우'),
#   ('정연우', '이재우'),
#   ('이재우', '길기모'),
#   ('이재우', '박성준'),
#   ('이재우', '이정화'),
#   ('이재우', '권택현'),
#   ('이재우', '정연규'),
#   ('이재우', '김호중'),
#   ('이재우', '정연우'),
#   ('이재우', '이재우'),
#   ('길기모', '박성준'),
#   ('길기모', '이정화'),
#   ('길기모', '권택현'),
#   ('길기모', '정연규'),
#   ('길기모', '김호중'),
#   ('길기모', '정연우'),
#   ('길기모', '이재우'),
#   ('박성준', '이정화'),
#   ('박성준', '권택현'),
#   ('박성준', '정연규'),
#   ('박성준', '김호중'),
#   ('박성준', '정연우'),
#   ('박성준', '이재우'),
#   ('이정화', '권택현'),
#   ('이정화', '정연규'),
#   ('이정화', '김호중'),
#   ('이정화', '정연우'),
#   ('이정화', '이재우'),
#   ('권택현', '정연규'),
#   ('권택현', '김호중'),
#   ('권택현', '정연우'),
#   ('권택현', '이재우'),
#   ('정연규', '김호중'),
#   ('정연규', '정연우'),
#   ('정연규', '이재우'),
#   ('김호중', '정연우'),
#   ('김호중', '이재우'),
#   ('정연우', '이재우')],
#  [('정재중', '김호중'),
#   ('정재중', '문병식'),
#   ('정재중', '정연우'),
#   ('정재중', '이순남'),
#   ('정재중', '임민수'),
#   ('정재중', '김수창'),
#   ('정재중', '이재우'),
#   ('정재중', '홍종국'),
#   ('정재중', '최근영'),
#   ('정재중', '김상원'),
#   ('정재중', '나유석'),
#   ('정재중', '신재범'),
#   ('정재중', '강준규'),
#   ('정재중', '강윤기'),
#   ('정재중', '이순남'),
#   ('정재중', '임민수'),
#   ('정재중', '김수창'),
#   ('정재중', '홍종국'),
#   ('정재중', '최근영'),
#   ('정재중', '김상원'),
#   ('정재중', '나유석'),
#   ('정재중', '신재범'),
#   ('정재중', '강준규'),
#   ('정재중', '강윤기'),
#   ('정재중', '김성원'),
#   ('정재중', '박정환'),
#   ('정재중', '이순남'),
#   ('정재중', '임민수'),
#   ('정재중', '김수창'),
#   ('정재중', '홍종국'),
#   ('정재중', '최근영'),
#   ('정재중', '김상원'),
#   ('정재중', '나유석'),
#   ('정재중', '신재범'),
#   ('정재중', '강준규'),
#   ('정재중', '강윤기'),
#   ('정재중', '김성원'),
#   ('정재중', '박정환'),
#   ('정재중', '송종원'),
#   ('정재중', '김경렬'),
#   ('정재중', '김광혁'),
#   ('정재중', '박석원'),
#   ('정재중', '김성균'),
#   ('정재중', '최광철'),
#   ('정재중', '최대경'),
#   ('김호중', '문병식'),
#   ('김호중', '정연우'),
#   ('김호중', '이순남'),
#   ('김호중', '임민수'),
#   ('김호중', '김수창'),
#   ('김호중', '이재우'),
#   ('김호중', '홍종국'),
#   ('김호중', '최근영'),
#   ('김호중', '김상원'),
#   ('김호중', '나유석'),
#   ('김호중', '신재범'),
#   ('김호중', '강준규'),
#   ('김호중', '강윤기'),
#   ('김호중', '이순남'),
#   ('김호중', '임민수'),
#   ('김호중', '김수창'),
#   ('김호중', '홍종국'),
#   ('김호중', '최근영'),
#   ('김호중', '김상원'),
#   ('김호중', '나유석'),
#   ('김호중', '신재범'),
#   ('김호중', '강준규'),
#   ('김호중', '강윤기'),
#   ('김호중', '김성원'),
#   ('김호중', '박정환'),
#   ('김호중', '이순남'),
#   ('김호중', '임민수'),
#   ('김호중', '김수창'),
#   ('김호중', '홍종국'),
#   ('김호중', '최근영'),
#   ('김호중', '김상원'),
#   ('김호중', '나유석'),
#   ('김호중', '신재범'),
#   ('김호중', '강준규'),
#   ('김호중', '강윤기'),
#   ('김호중', '김성원'),
#   ('김호중', '박정환'),
#   ('김호중', '송종원'),
#   ('김호중', '김경렬'),
#   ('김호중', '김광혁'),
#   ('김호중', '박석원'),
#   ('김호중', '김성균'),
#   ('김호중', '최광철'),
#   ('김호중', '최대경'),
#   ('문병식', '정연우'),
#   ('문병식', '이순남'),
#   ('문병식', '임민수'),
#   ('문병식', '김수창'),
#   ('문병식', '이재우'),
#   ('문병식', '홍종국'),
#   ('문병식', '최근영'),
#   ('문병식', '김상원'),
#   ('문병식', '나유석'),
#   ('문병식', '신재범'),
#   ('문병식', '강준규'),
#   ('문병식', '강윤기'),
#   ('문병식', '이순남'),
#   ('문병식', '임민수'),
#   ('문병식', '김수창'),
#   ('문병식', '홍종국'),
#   ('문병식', '최근영'),
#   ('문병식', '김상원'),
#   ('문병식', '나유석'),
#   ('문병식', '신재범'),
#   ('문병식', '강준규'),
#   ('문병식', '강윤기'),
#   ('문병식', '김성원'),
#   ('문병식', '박정환'),
#   ('문병식', '이순남'),
#   ('문병식', '임민수'),
#   ('문병식', '김수창'),
#   ('문병식', '홍종국'),
#   ('문병식', '최근영'),
#   ('문병식', '김상원'),
#   ('문병식', '나유석'),
#   ('문병식', '신재범'),
#   ('문병식', '강준규'),
#   ('문병식', '강윤기'),
#   ('문병식', '김성원'),
#   ('문병식', '박정환'),
#   ('문병식', '송종원'),
#   ('문병식', '김경렬'),
#   ('문병식', '김광혁'),
#   ('문병식', '박석원'),
#   ('문병식', '김성균'),
#   ('문병식', '최광철'),
#   ('문병식', '최대경'),
#   ('정연우', '이순남'),
#   ('정연우', '임민수'),
#   ('정연우', '김수창'),
#   ('정연우', '이재우'),
#   ('정연우', '홍종국'),
#   ('정연우', '최근영'),
#   ('정연우', '김상원'),
#   ('정연우', '나유석'),
#   ('정연우', '신재범'),
#   ('정연우', '강준규'),
#   ('정연우', '강윤기'),
#   ('정연우', '이순남'),
#   ('정연우', '임민수'),
#   ('정연우', '김수창'),
#   ('정연우', '홍종국'),
#   ('정연우', '최근영'),
#   ('정연우', '김상원'),
#   ('정연우', '나유석'),
#   ('정연우', '신재범'),
#   ('정연우', '강준규'),
#   ('정연우', '강윤기'),
#   ('정연우', '김성원'),
#   ('정연우', '박정환'),
#   ('정연우', '이순남'),
#   ('정연우', '임민수'),
#   ('정연우', '김수창'),
#   ('정연우', '홍종국'),
#   ('정연우', '최근영'),
#   ('정연우', '김상원'),
#   ('정연우', '나유석'),
#   ('정연우', '신재범'),
#   ('정연우', '강준규'),
#   ('정연우', '강윤기'),
#   ('정연우', '김성원'),
#   ('정연우', '박정환'),
#   ('정연우', '송종원'),
#   ('정연우', '김경렬'),
#   ('정연우', '김광혁'),
#   ('정연우', '박석원'),
#   ('정연우', '김성균'),
#   ('정연우', '최광철'),
#   ('정연우', '최대경'),
#   ('이순남', '임민수'),
#   ('이순남', '김수창'),
#   ('이순남', '이재우'),
#   ('이순남', '홍종국'),
#   ('이순남', '최근영'),
#   ('이순남', '김상원'),
#   ('이순남', '나유석'),
#   ('이순남', '신재범'),
#   ('이순남', '강준규'),
#   ('이순남', '강윤기'),
#   ('이순남', '이순남'),
#   ('이순남', '임민수'),
#   ('이순남', '김수창'),
#   ('이순남', '홍종국'),
#   ('이순남', '최근영'),
#   ('이순남', '김상원'),
#   ('이순남', '나유석'),
#   ('이순남', '신재범'),
#   ('이순남', '강준규'),
#   ('이순남', '강윤기'),
#   ('이순남', '김성원'),
#   ('이순남', '박정환'),
#   ('이순남', '이순남'),
#   ('이순남', '임민수'),
#   ('이순남', '김수창'),
#   ('이순남', '홍종국'),
#   ('이순남', '최근영'),
#   ('이순남', '김상원'),
#   ('이순남', '나유석'),
#   ('이순남', '신재범'),
#   ('이순남', '강준규'),
#   ('이순남', '강윤기'),
#   ('이순남', '김성원'),
#   ('이순남', '박정환'),
#   ('이순남', '송종원'),
#   ('이순남', '김경렬'),
#   ('이순남', '김광혁'),
#   ('이순남', '박석원'),
#   ('이순남', '김성균'),
#   ('이순남', '최광철'),
#   ('이순남', '최대경'),
#   ('임민수', '김수창'),
#   ('임민수', '이재우'),
#   ('임민수', '홍종국'),
#   ('임민수', '최근영'),
#   ('임민수', '김상원'),
#   ('임민수', '나유석'),
#   ('임민수', '신재범'),
#   ('임민수', '강준규'),
#   ('임민수', '강윤기'),
#   ('임민수', '이순남'),
#   ('임민수', '임민수'),
#   ('임민수', '김수창'),
#   ('임민수', '홍종국'),
#   ('임민수', '최근영'),
#   ('임민수', '김상원'),
#   ('임민수', '나유석'),
#   ('임민수', '신재범'),
#   ('임민수', '강준규'),
#   ('임민수', '강윤기'),
#   ('임민수', '김성원'),
#   ('임민수', '박정환'),
#   ('임민수', '이순남'),
#   ('임민수', '임민수'),
#   ('임민수', '김수창'),
#   ('임민수', '홍종국'),
#   ('임민수', '최근영'),
#   ('임민수', '김상원'),
#   ('임민수', '나유석'),
#   ('임민수', '신재범'),
#   ('임민수', '강준규'),
#   ('임민수', '강윤기'),
#   ('임민수', '김성원'),
#   ('임민수', '박정환'),
#   ('임민수', '송종원'),
#   ('임민수', '김경렬'),
#   ('임민수', '김광혁'),
#   ('임민수', '박석원'),
#   ('임민수', '김성균'),
#   ('임민수', '최광철'),
#   ('임민수', '최대경'),
#   ('김수창', '이재우'),
#   ('김수창', '홍종국'),
#   ('김수창', '최근영'),
#   ('김수창', '김상원'),
#   ('김수창', '나유석'),
#   ('김수창', '신재범'),
#   ('김수창', '강준규'),
#   ('김수창', '강윤기'),
#   ('김수창', '이순남'),
#   ('김수창', '임민수'),
#   ('김수창', '김수창'),
#   ('김수창', '홍종국'),
#   ('김수창', '최근영'),
#   ('김수창', '김상원'),
#   ('김수창', '나유석'),
#   ('김수창', '신재범'),
#   ('김수창', '강준규'),
#   ('김수창', '강윤기'),
#   ('김수창', '김성원'),
#   ('김수창', '박정환'),
#   ('김수창', '이순남'),
#   ('김수창', '임민수'),
#   ('김수창', '김수창'),
#   ('김수창', '홍종국'),
#   ('김수창', '최근영'),
#   ('김수창', '김상원'),
#   ('김수창', '나유석'),
#   ('김수창', '신재범'),
#   ('김수창', '강준규'),
#   ('김수창', '강윤기'),
#   ('김수창', '김성원'),
#   ('김수창', '박정환'),
#   ('김수창', '송종원'),
#   ('김수창', '김경렬'),
#   ('김수창', '김광혁'),
#   ('김수창', '박석원'),
#   ('김수창', '김성균'),
#   ('김수창', '최광철'),
#   ('김수창', '최대경'),
#   ('이재우', '홍종국'),
#   ('이재우', '최근영'),
#   ('이재우', '김상원'),
#   ('이재우', '나유석'),
#   ('이재우', '신재범'),
#   ('이재우', '강준규'),
#   ('이재우', '강윤기'),
#   ('이재우', '이순남'),
#   ('이재우', '임민수'),
#   ('이재우', '김수창'),
#   ('이재우', '홍종국'),
#   ('이재우', '최근영'),
#   ('이재우', '김상원'),
#   ('이재우', '나유석'),
#   ('이재우', '신재범'),
#   ('이재우', '강준규'),
#   ('이재우', '강윤기'),
#   ('이재우', '김성원'),
#   ('이재우', '박정환'),
#   ('이재우', '이순남'),
#   ('이재우', '임민수'),
#   ('이재우', '김수창'),
#   ('이재우', '홍종국'),
#   ('이재우', '최근영'),
#   ('이재우', '김상원'),
#   ('이재우', '나유석'),
#   ('이재우', '신재범'),
#   ('이재우', '강준규'),
#   ('이재우', '강윤기'),
#   ('이재우', '김성원'),
#   ('이재우', '박정환'),
#   ('이재우', '송종원'),
#   ('이재우', '김경렬'),
#   ('이재우', '김광혁'),
#   ('이재우', '박석원'),
#   ('이재우', '김성균'),
#   ('이재우', '최광철'),
#   ('이재우', '최대경'),
#   ('홍종국', '최근영'),
#   ('홍종국', '김상원'),
#   ('홍종국', '나유석'),
#   ('홍종국', '신재범'),
#   ('홍종국', '강준규'),
#   ('홍종국', '강윤기'),
#   ('홍종국', '이순남'),
#   ('홍종국', '임민수'),
#   ('홍종국', '김수창'),
#   ('홍종국', '홍종국'),
#   ('홍종국', '최근영'),
#   ('홍종국', '김상원'),
#   ('홍종국', '나유석'),
#   ('홍종국', '신재범'),
#   ('홍종국', '강준규'),
#   ('홍종국', '강윤기'),
#   ('홍종국', '김성원'),
#   ('홍종국', '박정환'),
#   ('홍종국', '이순남'),
#   ('홍종국', '임민수'),
#   ('홍종국', '김수창'),
#   ('홍종국', '홍종국'),
#   ('홍종국', '최근영'),
#   ('홍종국', '김상원'),
#   ('홍종국', '나유석'),
#   ('홍종국', '신재범'),
#   ('홍종국', '강준규'),
#   ('홍종국', '강윤기'),
#   ('홍종국', '김성원'),
#   ('홍종국', '박정환'),
#   ('홍종국', '송종원'),
#   ('홍종국', '김경렬'),
#   ('홍종국', '김광혁'),
#   ('홍종국', '박석원'),
#   ('홍종국', '김성균'),
#   ('홍종국', '최광철'),
#   ('홍종국', '최대경'),
#   ('최근영', '김상원'),
#   ('최근영', '나유석'),
#   ('최근영', '신재범'),
#   ('최근영', '강준규'),
#   ('최근영', '강윤기'),
#   ('최근영', '이순남'),
#   ('최근영', '임민수'),
#   ('최근영', '김수창'),
#   ('최근영', '홍종국'),
#   ('최근영', '최근영'),
#   ('최근영', '김상원'),
#   ('최근영', '나유석'),
#   ('최근영', '신재범'),
#   ('최근영', '강준규'),
#   ('최근영', '강윤기'),
#   ('최근영', '김성원'),
#   ('최근영', '박정환'),
#   ('최근영', '이순남'),
#   ('최근영', '임민수'),
#   ('최근영', '김수창'),
#   ('최근영', '홍종국'),
#   ('최근영', '최근영'),
#   ('최근영', '김상원'),
#   ('최근영', '나유석'),
#   ('최근영', '신재범'),
#   ('최근영', '강준규'),
#   ('최근영', '강윤기'),
#   ('최근영', '김성원'),
#   ('최근영', '박정환'),
#   ('최근영', '송종원'),
#   ('최근영', '김경렬'),
#   ('최근영', '김광혁'),
#   ('최근영', '박석원'),
#   ('최근영', '김성균'),
#   ('최근영', '최광철'),
#   ('최근영', '최대경'),
#   ('김상원', '나유석'),
#   ('김상원', '신재범'),
#   ('김상원', '강준규'),
#   ('김상원', '강윤기'),
#   ('김상원', '이순남'),
#   ('김상원', '임민수'),
#   ('김상원', '김수창'),
#   ('김상원', '홍종국'),
#   ('김상원', '최근영'),
#   ('김상원', '김상원'),
#   ('김상원', '나유석'),
#   ('김상원', '신재범'),
#   ('김상원', '강준규'),
#   ('김상원', '강윤기'),
#   ('김상원', '김성원'),
#   ('김상원', '박정환'),
#   ('김상원', '이순남'),
#   ('김상원', '임민수'),
#   ('김상원', '김수창'),
#   ('김상원', '홍종국'),
#   ('김상원', '최근영'),
#   ('김상원', '김상원'),
#   ('김상원', '나유석'),
#   ('김상원', '신재범'),
#   ('김상원', '강준규'),
#   ('김상원', '강윤기'),
#   ('김상원', '김성원'),
#   ('김상원', '박정환'),
#   ('김상원', '송종원'),
#   ('김상원', '김경렬'),
#   ('김상원', '김광혁'),
#   ('김상원', '박석원'),
#   ('김상원', '김성균'),
#   ('김상원', '최광철'),
#   ('김상원', '최대경'),
#   ('나유석', '신재범'),
#   ('나유석', '강준규'),
#   ('나유석', '강윤기'),
#   ('나유석', '이순남'),
#   ('나유석', '임민수'),
#   ('나유석', '김수창'),
#   ('나유석', '홍종국'),
#   ('나유석', '최근영'),
#   ('나유석', '김상원'),
#   ('나유석', '나유석'),
#   ('나유석', '신재범'),
#   ('나유석', '강준규'),
#   ('나유석', '강윤기'),
#   ('나유석', '김성원'),
#   ('나유석', '박정환'),
#   ('나유석', '이순남'),
#   ('나유석', '임민수'),
#   ('나유석', '김수창'),
#   ('나유석', '홍종국'),
#   ('나유석', '최근영'),
#   ('나유석', '김상원'),
#   ('나유석', '나유석'),
#   ('나유석', '신재범'),
#   ('나유석', '강준규'),
#   ('나유석', '강윤기'),
#   ('나유석', '김성원'),
#   ('나유석', '박정환'),
#   ('나유석', '송종원'),
#   ('나유석', '김경렬'),
#   ('나유석', '김광혁'),
#   ('나유석', '박석원'),
#   ('나유석', '김성균'),
#   ('나유석', '최광철'),
#   ('나유석', '최대경'),
#   ('신재범', '강준규'),
#   ('신재범', '강윤기'),
#   ('신재범', '이순남'),
#   ('신재범', '임민수'),
#   ('신재범', '김수창'),
#   ('신재범', '홍종국'),
#   ('신재범', '최근영'),
#   ('신재범', '김상원'),
#   ('신재범', '나유석'),
#   ('신재범', '신재범'),
#   ('신재범', '강준규'),
#   ('신재범', '강윤기'),
#   ('신재범', '김성원'),
#   ('신재범', '박정환'),
#   ('신재범', '이순남'),
#   ('신재범', '임민수'),
#   ('신재범', '김수창'),
#   ('신재범', '홍종국'),
#   ('신재범', '최근영'),
#   ('신재범', '김상원'),
#   ('신재범', '나유석'),
#   ('신재범', '신재범'),
#   ('신재범', '강준규'),
#   ('신재범', '강윤기'),
#   ('신재범', '김성원'),
#   ('신재범', '박정환'),
#   ('신재범', '송종원'),
#   ('신재범', '김경렬'),
#   ('신재범', '김광혁'),
#   ('신재범', '박석원'),
#   ('신재범', '김성균'),
#   ('신재범', '최광철'),
#   ('신재범', '최대경'),
#   ('강준규', '강윤기'),
#   ('강준규', '이순남'),
#   ('강준규', '임민수'),
#   ('강준규', '김수창'),
#   ('강준규', '홍종국'),
#   ('강준규', '최근영'),
#   ('강준규', '김상원'),
#   ('강준규', '나유석'),
#   ('강준규', '신재범'),
#   ('강준규', '강준규'),
#   ('강준규', '강윤기'),
#   ('강준규', '김성원'),
#   ('강준규', '박정환'),
#   ('강준규', '이순남'),
#   ('강준규', '임민수'),
#   ('강준규', '김수창'),
#   ('강준규', '홍종국'),
#   ('강준규', '최근영'),
#   ('강준규', '김상원'),
#   ('강준규', '나유석'),
#   ('강준규', '신재범'),
#   ('강준규', '강준규'),
#   ('강준규', '강윤기'),
#   ('강준규', '김성원'),
#   ('강준규', '박정환'),
#   ('강준규', '송종원'),
#   ('강준규', '김경렬'),
#   ('강준규', '김광혁'),
#   ('강준규', '박석원'),
#   ('강준규', '김성균'),
#   ('강준규', '최광철'),
#   ('강준규', '최대경'),
#   ('강윤기', '이순남'),
#   ('강윤기', '임민수'),
#   ('강윤기', '김수창'),
#   ('강윤기', '홍종국'),
#   ('강윤기', '최근영'),
#   ('강윤기', '김상원'),
#   ('강윤기', '나유석'),
#   ('강윤기', '신재범'),
#   ('강윤기', '강준규'),
#   ('강윤기', '강윤기'),
#   ('강윤기', '김성원'),
#   ('강윤기', '박정환'),
#   ('강윤기', '이순남'),
#   ('강윤기', '임민수'),
#   ('강윤기', '김수창'),
#   ('강윤기', '홍종국'),
#   ('강윤기', '최근영'),
#   ('강윤기', '김상원'),
#   ('강윤기', '나유석'),
#   ('강윤기', '신재범'),
#   ('강윤기', '강준규'),
#   ('강윤기', '강윤기'),
#   ('강윤기', '김성원'),
#   ('강윤기', '박정환'),
#   ('강윤기', '송종원'),
#   ('강윤기', '김경렬'),
#   ('강윤기', '김광혁'),
#   ('강윤기', '박석원'),
#   ('강윤기', '김성균'),
#   ('강윤기', '최광철'),
#   ('강윤기', '최대경'),
#   ('이순남', '임민수'),
#   ('이순남', '김수창'),
#   ('이순남', '홍종국'),
#   ('이순남', '최근영'),
#   ('이순남', '김상원'),
#   ('이순남', '나유석'),
#   ('이순남', '신재범'),
#   ('이순남', '강준규'),
#   ('이순남', '강윤기'),
#   ('이순남', '김성원'),
#   ('이순남', '박정환'),
#   ('이순남', '이순남'),
#   ('이순남', '임민수'),
#   ('이순남', '김수창'),
#   ('이순남', '홍종국'),
#   ('이순남', '최근영'),
#   ('이순남', '김상원'),
#   ('이순남', '나유석'),
#   ('이순남', '신재범'),
#   ('이순남', '강준규'),
#   ('이순남', '강윤기'),
#   ('이순남', '김성원'),
#   ('이순남', '박정환'),
#   ('이순남', '송종원'),
#   ('이순남', '김경렬'),
#   ('이순남', '김광혁'),
#   ('이순남', '박석원'),
#   ('이순남', '김성균'),
#   ('이순남', '최광철'),
#   ('이순남', '최대경'),
#   ('임민수', '김수창'),
#   ('임민수', '홍종국'),
#   ('임민수', '최근영'),
#   ('임민수', '김상원'),
#   ('임민수', '나유석'),
#   ('임민수', '신재범'),
#   ('임민수', '강준규'),
#   ('임민수', '강윤기'),
#   ('임민수', '김성원'),
#   ('임민수', '박정환'),
#   ('임민수', '이순남'),
#   ('임민수', '임민수'),
#   ('임민수', '김수창'),
#   ('임민수', '홍종국'),
#   ('임민수', '최근영'),
#   ('임민수', '김상원'),
#   ('임민수', '나유석'),
#   ('임민수', '신재범'),
#   ('임민수', '강준규'),
#   ('임민수', '강윤기'),
#   ('임민수', '김성원'),
#   ('임민수', '박정환'),
#   ('임민수', '송종원'),
#   ('임민수', '김경렬'),
#   ('임민수', '김광혁'),
#   ('임민수', '박석원'),
#   ('임민수', '김성균'),
#   ('임민수', '최광철'),
#   ('임민수', '최대경'),
#   ('김수창', '홍종국'),
#   ('김수창', '최근영'),
#   ('김수창', '김상원'),
#   ('김수창', '나유석'),
#   ('김수창', '신재범'),
#   ('김수창', '강준규'),
#   ('김수창', '강윤기'),
#   ('김수창', '김성원'),
#   ('김수창', '박정환'),
#   ('김수창', '이순남'),
#   ('김수창', '임민수'),
#   ('김수창', '김수창'),
#   ('김수창', '홍종국'),
#   ('김수창', '최근영'),
#   ('김수창', '김상원'),
#   ('김수창', '나유석'),
#   ('김수창', '신재범'),
#   ('김수창', '강준규'),
#   ('김수창', '강윤기'),
#   ('김수창', '김성원'),
#   ('김수창', '박정환'),
#   ('김수창', '송종원'),
#   ('김수창', '김경렬'),
#   ('김수창', '김광혁'),
#   ('김수창', '박석원'),
#   ('김수창', '김성균'),
#   ('김수창', '최광철'),
#   ('김수창', '최대경'),
#   ('홍종국', '최근영'),
#   ('홍종국', '김상원'),
#   ('홍종국', '나유석'),
#   ('홍종국', '신재범'),
#   ('홍종국', '강준규'),
#   ('홍종국', '강윤기'),
#   ('홍종국', '김성원'),
#   ('홍종국', '박정환'),
#   ('홍종국', '이순남'),
#   ('홍종국', '임민수'),
#   ('홍종국', '김수창'),
#   ('홍종국', '홍종국'),
#   ('홍종국', '최근영'),
#   ('홍종국', '김상원'),
#   ('홍종국', '나유석'),
#   ('홍종국', '신재범'),
#   ('홍종국', '강준규'),
#   ('홍종국', '강윤기'),
#   ('홍종국', '김성원'),
#   ('홍종국', '박정환'),
#   ('홍종국', '송종원'),
#   ('홍종국', '김경렬'),
#   ('홍종국', '김광혁'),
#   ('홍종국', '박석원'),
#   ('홍종국', '김성균'),
#   ('홍종국', '최광철'),
#   ('홍종국', '최대경'),
#   ('최근영', '김상원'),
#   ('최근영', '나유석'),
#   ('최근영', '신재범'),
#   ('최근영', '강준규'),
#   ('최근영', '강윤기'),
#   ('최근영', '김성원'),
#   ('최근영', '박정환'),
#   ('최근영', '이순남'),
#   ('최근영', '임민수'),
#   ('최근영', '김수창'),
#   ('최근영', '홍종국'),
#   ('최근영', '최근영'),
#   ('최근영', '김상원'),
#   ('최근영', '나유석'),
#   ('최근영', '신재범'),
#   ('최근영', '강준규'),
#   ('최근영', '강윤기'),
#   ('최근영', '김성원'),
#   ('최근영', '박정환'),
#   ('최근영', '송종원'),
#   ('최근영', '김경렬'),
#   ('최근영', '김광혁'),
#   ('최근영', '박석원'),
#   ('최근영', '김성균'),
#   ('최근영', '최광철'),
#   ('최근영', '최대경'),
#   ('김상원', '나유석'),
#   ('김상원', '신재범'),
#   ('김상원', '강준규'),
#   ('김상원', '강윤기'),
#   ('김상원', '김성원'),
#   ('김상원', '박정환'),
#   ('김상원', '이순남'),
#   ('김상원', '임민수'),
#   ('김상원', '김수창'),
#   ('김상원', '홍종국'),
#   ('김상원', '최근영'),
#   ('김상원', '김상원'),
#   ('김상원', '나유석'),
#   ('김상원', '신재범'),
#   ('김상원', '강준규'),
#   ('김상원', '강윤기'),
#   ('김상원', '김성원'),
#   ('김상원', '박정환'),
#   ('김상원', '송종원'),
#   ('김상원', '김경렬'),
#   ('김상원', '김광혁'),
#   ('김상원', '박석원'),
#   ('김상원', '김성균'),
#   ('김상원', '최광철'),
#   ('김상원', '최대경'),
#   ('나유석', '신재범'),
#   ('나유석', '강준규'),
#   ('나유석', '강윤기'),
#   ('나유석', '김성원'),
#   ('나유석', '박정환'),
#   ('나유석', '이순남'),
#   ('나유석', '임민수'),
#   ('나유석', '김수창'),
#   ('나유석', '홍종국'),
#   ('나유석', '최근영'),
#   ('나유석', '김상원'),
#   ('나유석', '나유석'),
#   ('나유석', '신재범'),
#   ('나유석', '강준규'),
#   ('나유석', '강윤기'),
#   ('나유석', '김성원'),
#   ('나유석', '박정환'),
#   ('나유석', '송종원'),
#   ('나유석', '김경렬'),
#   ('나유석', '김광혁'),
#   ('나유석', '박석원'),
#   ('나유석', '김성균'),
#   ('나유석', '최광철'),
#   ('나유석', '최대경'),
#   ('신재범', '강준규'),
#   ('신재범', '강윤기'),
#   ('신재범', '김성원'),
#   ('신재범', '박정환'),
#   ('신재범', '이순남'),
#   ('신재범', '임민수'),
#   ('신재범', '김수창'),
#   ('신재범', '홍종국'),
#   ('신재범', '최근영'),
#   ('신재범', '김상원'),
#   ('신재범', '나유석'),
#   ('신재범', '신재범'),
#   ('신재범', '강준규'),
#   ('신재범', '강윤기'),
#   ('신재범', '김성원'),
#   ('신재범', '박정환'),
#   ('신재범', '송종원'),
#   ('신재범', '김경렬'),
#   ('신재범', '김광혁'),
#   ('신재범', '박석원'),
#   ('신재범', '김성균'),
#   ('신재범', '최광철'),
#   ('신재범', '최대경'),
#   ('강준규', '강윤기'),
#   ('강준규', '김성원'),
#   ('강준규', '박정환'),
#   ('강준규', '이순남'),
#   ('강준규', '임민수'),
#   ('강준규', '김수창'),
#   ('강준규', '홍종국'),
#   ('강준규', '최근영'),
#   ('강준규', '김상원'),
#   ('강준규', '나유석'),
#   ('강준규', '신재범'),
#   ('강준규', '강준규'),
#   ('강준규', '강윤기'),
#   ('강준규', '김성원'),
#   ('강준규', '박정환'),
#   ('강준규', '송종원'),
#   ('강준규', '김경렬'),
#   ('강준규', '김광혁'),
#   ('강준규', '박석원'),
#   ('강준규', '김성균'),
#   ('강준규', '최광철'),
#   ('강준규', '최대경'),
#   ('강윤기', '김성원'),
#   ('강윤기', '박정환'),
#   ('강윤기', '이순남'),
#   ('강윤기', '임민수'),
#   ('강윤기', '김수창'),
#   ('강윤기', '홍종국'),
#   ('강윤기', '최근영'),
#   ('강윤기', '김상원'),
#   ('강윤기', '나유석'),
#   ('강윤기', '신재범'),
#   ('강윤기', '강준규'),
#   ('강윤기', '강윤기'),
#   ('강윤기', '김성원'),
#   ('강윤기', '박정환'),
#   ('강윤기', '송종원'),
#   ('강윤기', '김경렬'),
#   ('강윤기', '김광혁'),
#   ('강윤기', '박석원'),
#   ('강윤기', '김성균'),
#   ('강윤기', '최광철'),
#   ('강윤기', '최대경'),
#   ('김성원', '박정환'),
#   ('김성원', '이순남'),
#   ('김성원', '임민수'),
#   ('김성원', '김수창'),
#   ('김성원', '홍종국'),
#   ('김성원', '최근영'),
#   ('김성원', '김상원'),
#   ('김성원', '나유석'),
#   ('김성원', '신재범'),
#   ('김성원', '강준규'),
#   ('김성원', '강윤기'),
#   ('김성원', '김성원'),
#   ('김성원', '박정환'),
#   ('김성원', '송종원'),
#   ('김성원', '김경렬'),
#   ('김성원', '김광혁'),
#   ('김성원', '박석원'),
#   ('김성원', '김성균'),
#   ('김성원', '최광철'),
#   ('김성원', '최대경'),
#   ('박정환', '이순남'),
#   ('박정환', '임민수'),
#   ('박정환', '김수창'),
#   ('박정환', '홍종국'),
#   ('박정환', '최근영'),
#   ('박정환', '김상원'),
#   ('박정환', '나유석'),
#   ('박정환', '신재범'),
#   ('박정환', '강준규'),
#   ('박정환', '강윤기'),
#   ('박정환', '김성원'),
#   ('박정환', '박정환'),
#   ('박정환', '송종원'),
#   ('박정환', '김경렬'),
#   ('박정환', '김광혁'),
#   ('박정환', '박석원'),
#   ('박정환', '김성균'),
#   ('박정환', '최광철'),
#   ('박정환', '최대경'),
#   ('이순남', '임민수'),
#   ('이순남', '김수창'),
#   ('이순남', '홍종국'),
#   ('이순남', '최근영'),
#   ('이순남', '김상원'),
#   ('이순남', '나유석'),
#   ('이순남', '신재범'),
#   ('이순남', '강준규'),
#   ('이순남', '강윤기'),
#   ('이순남', '김성원'),
#   ('이순남', '박정환'),
#   ('이순남', '송종원'),
#   ('이순남', '김경렬'),
#   ('이순남', '김광혁'),
#   ('이순남', '박석원'),
#   ('이순남', '김성균'),
#   ('이순남', '최광철'),
#   ('이순남', '최대경'),
#   ('임민수', '김수창'),
#   ('임민수', '홍종국'),
#   ('임민수', '최근영'),
#   ('임민수', '김상원'),
#   ('임민수', '나유석'),
#   ('임민수', '신재범'),
#   ('임민수', '강준규'),
#   ('임민수', '강윤기'),
#   ('임민수', '김성원'),
#   ('임민수', '박정환'),
#   ('임민수', '송종원'),
#   ('임민수', '김경렬'),
#   ('임민수', '김광혁'),
#   ('임민수', '박석원'),
#   ('임민수', '김성균'),
#   ('임민수', '최광철'),
#   ('임민수', '최대경'),
#   ('김수창', '홍종국'),
#   ('김수창', '최근영'),
#   ('김수창', '김상원'),
#   ('김수창', '나유석'),
#   ('김수창', '신재범'),
#   ('김수창', '강준규'),
#   ('김수창', '강윤기'),
#   ('김수창', '김성원'),
#   ('김수창', '박정환'),
#   ('김수창', '송종원'),
#   ('김수창', '김경렬'),
#   ('김수창', '김광혁'),
#   ('김수창', '박석원'),
#   ('김수창', '김성균'),
#   ('김수창', '최광철'),
#   ('김수창', '최대경'),
#   ('홍종국', '최근영'),
#   ('홍종국', '김상원'),
#   ('홍종국', '나유석'),
#   ('홍종국', '신재범'),
#   ('홍종국', '강준규'),
#   ('홍종국', '강윤기'),
#   ('홍종국', '김성원'),
#   ('홍종국', '박정환'),
#   ('홍종국', '송종원'),
#   ('홍종국', '김경렬'),
#   ('홍종국', '김광혁'),
#   ('홍종국', '박석원'),
#   ('홍종국', '김성균'),
#   ('홍종국', '최광철'),
#   ('홍종국', '최대경'),
#   ('최근영', '김상원'),
#   ('최근영', '나유석'),
#   ('최근영', '신재범'),
#   ('최근영', '강준규'),
#   ('최근영', '강윤기'),
#   ('최근영', '김성원'),
#   ('최근영', '박정환'),
#   ('최근영', '송종원'),
#   ('최근영', '김경렬'),
#   ('최근영', '김광혁'),
#   ('최근영', '박석원'),
#   ('최근영', '김성균'),
#   ('최근영', '최광철'),
#   ('최근영', '최대경'),
#   ('김상원', '나유석'),
#   ('김상원', '신재범'),
#   ('김상원', '강준규'),
#   ('김상원', '강윤기'),
#   ('김상원', '김성원'),
#   ('김상원', '박정환'),
#   ('김상원', '송종원'),
#   ('김상원', '김경렬'),
#   ('김상원', '김광혁'),
#   ('김상원', '박석원'),
#   ('김상원', '김성균'),
#   ('김상원', '최광철'),
#   ('김상원', '최대경'),
#   ('나유석', '신재범'),
#   ('나유석', '강준규'),
#   ('나유석', '강윤기'),
#   ('나유석', '김성원'),
#   ('나유석', '박정환'),
#   ('나유석', '송종원'),
#   ('나유석', '김경렬'),
#   ('나유석', '김광혁'),
#   ('나유석', '박석원'),
#   ('나유석', '김성균'),
#   ('나유석', '최광철'),
#   ('나유석', '최대경'),
#   ('신재범', '강준규'),
#   ('신재범', '강윤기'),
#   ('신재범', '김성원'),
#   ('신재범', '박정환'),
#   ('신재범', '송종원'),
#   ('신재범', '김경렬'),
#   ('신재범', '김광혁'),
#   ('신재범', '박석원'),
#   ('신재범', '김성균'),
#   ('신재범', '최광철'),
#   ('신재범', '최대경'),
#   ('강준규', '강윤기'),
#   ('강준규', '김성원'),
#   ('강준규', '박정환'),
#   ('강준규', '송종원'),
#   ('강준규', '김경렬'),
#   ('강준규', '김광혁'),
#   ('강준규', '박석원'),
#   ('강준규', '김성균'),
#   ('강준규', '최광철'),
#   ('강준규', '최대경'),
#   ('강윤기', '김성원'),
#   ('강윤기', '박정환'),
#   ('강윤기', '송종원'),
#   ('강윤기', '김경렬'),
#   ('강윤기', '김광혁'),
#   ('강윤기', '박석원'),
#   ('강윤기', '김성균'),
#   ('강윤기', '최광철'),
#   ('강윤기', '최대경'),
#   ('김성원', '박정환'),
#   ...],
#  [('오익근', '오익근'), ('오익근', '오익근'), ('오익근', '오익근')],
#  [('김성원', '정기동'),
#   ('김성원', '정기동'),
#   ('김성원', '이정훈'),
#   ('김성원', '김봉진'),
#   ('김성원', '이정훈'),
#   ('김성원', '김봉진'),
#   ('김성원', '김상혁'),
#   ('정기동', '정기동'),
#   ('정기동', '이정훈'),
#   ('정기동', '김봉진'),
#   ('정기동', '이정훈'),
#   ('정기동', '김봉진'),
#   ('정기동', '김상혁'),
#   ('정기동', '이정훈'),
#   ('정기동', '김봉진'),
#   ('정기동', '이정훈'),
#   ('정기동', '김봉진'),
#   ('정기동', '김상혁'),
#   ('이정훈', '김봉진'),
#   ('이정훈', '이정훈'),
#   ('이정훈', '김봉진'),
#   ('이정훈', '김상혁'),
#   ('김봉진', '이정훈'),
#   ('김봉진', '김봉진'),
#   ('김봉진', '김상혁'),
#   ('이정훈', '김봉진'),
#   ('이정훈', '김상혁'),
#   ('김봉진', '김상혁')],
#  [('박현식', '박현식'),
#   ('박현식', '이성영'),
#   ('박현식', '이성영'),
#   ('박현식', '정회민'),
#   ('박현식', '이성영'),
#   ('박현식', '이성영'),
#   ('박현식', '정회민'),
#   ('이성영', '이성영'),
#   ('이성영', '정회민'),
#   ('이성영', '정회민')],
#  [('이지원', '김병철'),
#   ('이지원', '이창세'),
#   ('이지원', '조홍희'),
#   ('이지원', '김병철'),
#   ('이지원', '이창세'),
#   ('이지원', '조홍희'),
#   ('이지원', '김창수'),
#   ('이지원', '원윤희'),
#   ('이지원', '김병철'),
#   ('이지원', '이창세'),
#   ('이지원', '김창수'),
#   ('이지원', '원윤희'),
#   ('이지원', '김성호'),
#   ('김병철', '이창세'),
#   ('김병철', '조홍희'),
#   ('김병철', '김병철'),
#   ('김병철', '이창세'),
#   ('김병철', '조홍희'),
#   ('김병철', '김창수'),
#   ('김병철', '원윤희'),
#   ('김병철', '김병철'),
#   ('김병철', '이창세'),
#   ('김병철', '김창수'),
#   ('김병철', '원윤희'),
#   ('김병철', '김성호'),
#   ('이창세', '조홍희'),
#   ('이창세', '김병철'),
#   ('이창세', '이창세'),
#   ('이창세', '조홍희'),
#   ('이창세', '김창수'),
#   ('이창세', '원윤희'),
#   ('이창세', '김병철'),
#   ('이창세', '이창세'),
#   ('이창세', '김창수'),
#   ('이창세', '원윤희'),
#   ('이창세', '김성호'),
#   ('조홍희', '김병철'),
#   ('조홍희', '이창세'),
#   ('조홍희', '조홍희'),
#   ('조홍희', '김창수'),
#   ('조홍희', '원윤희'),
#   ('조홍희', '김병철'),
#   ('조홍희', '이창세'),
#   ('조홍희', '김창수'),
#   ('조홍희', '원윤희'),
#   ('조홍희', '김성호'),
#   ('김병철', '이창세'),
#   ('김병철', '조홍희'),
#   ('김병철', '김창수'),
#   ('김병철', '원윤희'),
#   ('김병철', '김병철'),
#   ('김병철', '이창세'),
#   ('김병철', '김창수'),
#   ('김병철', '원윤희'),
#   ('김병철', '김성호'),
#   ('이창세', '조홍희'),
#   ('이창세', '김창수'),
#   ('이창세', '원윤희'),
#   ('이창세', '김병철'),
#   ('이창세', '이창세'),
#   ('이창세', '김창수'),
#   ('이창세', '원윤희'),
#   ('이창세', '김성호'),
#   ('조홍희', '김창수'),
#   ('조홍희', '원윤희'),
#   ('조홍희', '김병철'),
#   ('조홍희', '이창세'),
#   ('조홍희', '김창수'),
#   ('조홍희', '원윤희'),
#   ('조홍희', '김성호'),
#   ('김창수', '원윤희'),
#   ('김창수', '김병철'),
#   ('김창수', '이창세'),
#   ('김창수', '김창수'),
#   ('김창수', '원윤희'),
#   ('김창수', '김성호'),
#   ('원윤희', '김병철'),
#   ('원윤희', '이창세'),
#   ('원윤희', '김창수'),
#   ('원윤희', '원윤희'),
#   ('원윤희', '김성호'),
#   ('김병철', '이창세'),
#   ('김병철', '김창수'),
#   ('김병철', '원윤희'),
#   ('김병철', '김성호'),
#   ('이창세', '김창수'),
#   ('이창세', '원윤희'),
#   ('이창세', '김성호'),
#   ('김창수', '원윤희'),
#   ('김창수', '김성호'),
#   ('원윤희', '김성호')],
#  [('김범철', '송혁'),
#   ('김범철', '송혁'),
#   ('김범철', '김범철'),
#   ('김범철', '송혁'),
#   ('김범철', '김범철'),
#   ('송혁', '송혁'),
#   ('송혁', '김범철'),
#   ('송혁', '송혁'),
#   ('송혁', '김범철'),
#   ('송혁', '김범철'),
#   ('송혁', '송혁'),
#   ('송혁', '김범철'),
#   ('김범철', '송혁'),
#   ('김범철', '김범철'),
#   ('송혁', '김범철')],
#  [('양홍석', '양홍석')]]
