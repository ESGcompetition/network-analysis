# %% [markdown]
# <OpenDartReader 예제>
#
# https://github.com/FinanceData/OpenDartReader
#
#
# <OpenDart 전자공시 API>
#
# https://opendart.fss.or.kr/
#
#
# <OpenDartReader 레퍼런스 메뉴얼>
#
# https://nbviewer.org/github/FinanceData/OpenDartReader/blob/master/docs/OpenDartReader_reference_manual.ipynb

# %% [markdown]
# # API 설치

# %%
# OpenDart설치 및 구글마운트
'''
import os, sys
from google.colab import drive
drive.mount('/content/drive')

my_path = '/content/notebooks'
# Colab Notebooks 안에 my_env 폴더에 패키지 저장
os.symlink('/content/drive/My Drive/Colab Notebooks/package', my_path)
sys.path.insert(0, my_path)
'''
# Out:
# Mounted at /content/drive

# %%
#설치
'''
# !pip install --target=$my_path opendartreader
'''
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 55.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 89.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 33.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 39.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 77.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 26.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 22.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# # 코랩에 패키지 가져오기

# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')

my_path = '/content/package'
save_path = '/content/drive/MyDrive/Colab Notebooks/package' 

os.symlink(save_path, my_path)
sys.path.insert(0, my_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---

# %%
import OpenDartReader

### 0. 객체 생성 ###
# 객체 생성 (API KEY 지정) 
api_key = 'ebd213d75beaeac7659874cda6ec4ec28394fdc3'

dart = OpenDartReader(api_key)

# %% [markdown]
# # test

# %%
dart.list('삼성전자')
# Out:
#      corp_code corp_name stock_code corp_cls                     report_nm
# 0     00126380      삼성전자     005930        Y             주식등의대량보유상황보고서(일반)  \
# 1     00126380      삼성전자     005930        Y                  기타경영사항(자율공시)
# 2     00126380      삼성전자     005930        Y                  기타경영사항(자율공시)
# 3     00126380      삼성전자     005930        Y                     현금ㆍ현물배당결정
# 4     00126380      삼성전자     005930        Y  [기재정정]연결재무제표기준영업(잠정)실적(공정공시)
# ...        ...       ...        ...      ...                           ...
# 5731  00126380      삼성전자     005930        Y                  채무보증(담보제공포함)
# 5732  00126380      삼성전자     005930        Y                 최대주주등을위한금전의대여
# 5733  00126380      삼성전자     005930        Y               감사보고서 (1999.12)
# 5734  00126380      삼성전자     005930        Y         [기재정정]반기보고서 (1999.06)
# 5735  00126380      삼성전자     005930        Y         [기재정정]사업보고서 (1998.12)
#
#             rcept_no  flr_nm  rcept_dt rm
# ...

# %%
corp_name_list = ['다올투자증권','다우데이타','SK증권','메리츠금융지주','NH투자증권','한국금융지주','다우기술','대신증권','유안타증권','삼성증권','유진증권','한양증권','현대차증권','이베스트투자증권','교보증권','DB금융투자','유화증권','부국증권','신영증권','코리아에셋투자증권','상상인증권','키움증권']
corp_code_list = []

# %%
for i in corp_name_list:
    for k in [2020,2021,2022]:
        corp_code_list.append(dart.find_corp_code(i))
        df = dart.report(i,'임원',k)
        df = dart.report(i,'최대주주',k)
        print(i)
# Out:
# 다올투자증권
# 다올투자증권
# 다올투자증권
# 다우데이타
# 다우데이타
# 다우데이타
# SK증권
# SK증권
# SK증권
# 메리츠금융지주
# 메리츠금융지주
# 메리츠금융지주
# NH투자증권
# NH투자증권
# NH투자증권
# 한국금융지주
# 한국금융지주
# 한국금융지주
# 다우기술
# 다우기술
# 다우기술
# 대신증권
# 대신증권
# 대신증권
# 유안타증권
# 유안타증권
# 유안타증권
# 삼성증권
# 삼성증권
# 삼성증권
# 유진증권
# 유진증권
# 유진증권
# 한양증권
# 한양증권
# 한양증권
# 현대차증권
# 현대차증권
# 현대차증권
# 이베스트투자증권
# 이베스트투자증권
# 이베스트투자증권
# 교보증권
# 교보증권
# 교보증권
# DB금융투자
# DB금융투자
# DB금융투자
# 유화증권
# 유화증권
# 유화증권
# 부국증권
# 부국증권
# 부국증권
# 신영증권
# 신영증권
# 신영증권
# 코리아에셋투자증권
# 코리아에셋투자증권
# 코리아에셋투자증권
# 상상인증권
# 상상인증권
# 상상인증권
# 키움증권
# 키움증권
# 키움증권

# %%
dart.company('005930')
# Out:
# {'status': '000',
#  'message': '정상',
#  'corp_code': '00126380',
#  'corp_name': '삼성전자(주)',
#  'corp_name_eng': 'SAMSUNG ELECTRONICS CO,.LTD',
#  'stock_name': '삼성전자',
#  'stock_code': '005930',
#  'ceo_nm': '한종희, 경계현',
#  'corp_cls': 'Y',
#  'jurir_no': '1301110006246',
#  'bizr_no': '1248100998',
#  'adres': '경기도 수원시 영통구  삼성로 129 (매탄동)',
#  'hm_url': 'www.samsung.com/sec',
#  'ir_url': '',
#  'phn_no': '02-2255-0114',
#  'fax_no': '031-200-7538',
#  'induty_code': '264',
#  'est_dt': '19690113',
#  'acc_mt': '12'}

# %%
dart.company_by_name('삼성전자')
# Out:
# [{'status': '000',
#   'message': '정상',
#   'corp_code': '00258999',
#   'corp_name': '삼성전자 서비스주식회사',
#   'corp_name_eng': 'SAMSUNNG ELECTRONICS SERVICE CO., LTD',
#   'stock_name': '삼성전자서비스',
#   'stock_code': '',
#   'ceo_nm': '송봉섭',
#   'corp_cls': 'E',
#   'jurir_no': '1301110049139',
#   'bizr_no': '1248158485',
#   'adres': '경기도 수원시 영통구 삼성로 290 (원천동)',
#   'hm_url': 'www.samsungsvc.co.kr',
#   'ir_url': '',
#   'phn_no': '031-270-2177',
#   'fax_no': '031-270-2106',
#   'induty_code': '95',
#   'est_dt': '19981027',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01345812',
#   'corp_name': '삼성전자서비스씨에스 주식회사',
#   'corp_name_eng': 'SAMSUNG ELECTRONICS SERVICE CUSTOMER SATISFACTION., LTD.',
#   'stock_name': '삼성전자서비스씨에스',
#   'stock_code': '',
#   'ceo_nm': '이명옥',
#   'corp_cls': 'E',
#   'jurir_no': '1358110352541',
#   'bizr_no': '7898701103',
#   'adres': '경기도 수원시 영통구 중부대로 324 (매탄동, KT동수원지사)',
#   'hm_url': '',
#   'ir_url': '',
# ...

# %% [markdown]
# # 임원ㆍ주요주주 소유보고

# %%
dart.major_shareholders_exec('삼성전자')
# Out:
#            rcept_no    rcept_dt corp_code corp_name repror isu_exctv_rgist_at
# 0    20210507000833  2021-05-07  00126380      삼성전자    노태문              비등기임원  \
# 1    20210507000808  2021-05-07  00126380      삼성전자    최윤호               등기임원
# 2    20210511000205  2021-05-11  00126380      삼성전자    고재필              비등기임원
# 3    20210510000900  2021-05-11  00126380      삼성전자    조필주              비등기임원
# 4    20210512000475  2021-05-12  00126380      삼성전자    김태영              비등기임원
# ..              ...         ...       ...       ...    ...                ...
# 222  20230302000431  2023-03-02  00126380      삼성전자    안재용              비등기임원
# 223  20230316000646  2023-03-16  00126380      삼성전자    안재용              비등기임원
# 224  20230324000884  2023-03-24  00126380      삼성전자    경계현               등기임원
# 225  20230406002362  2023-04-06  00126380      삼성전자    김이태              비등기임원
# 226  20230412002146  2023-04-12  00126380      삼성전자    김이태              비등기임원
#
# ...

# %% [markdown]
# * rcept_no: 접수번호
# * rcept_dt: 접수일자
# * corp_code: 종목코드
# * corp_name: 회사명
# * repror: 대표보고자
# * isu_exctv_rgist_at: 발행 회사 관계 임원(등기여부)
# * isu_exctv_ofcps: 발행 회사 관계 임원 직위
# * isu_main_shrholdr: 발행 회사 관계 주요 주주
# * sp_stock_lmp_cnt: 특정 증권 등 소유 수
# * sp_stock_lmp_irds_cnt: 특정 증권 등 소유 증감 수
# * sp_stock_lmp_rate: 특정 증권 등 소유 비율
# * sp_stock_lmp_irds_rate: 특정 증권 등 소유 증감 비율

# %% [markdown]
# ## xml 파일 받아오기..ㅇㄴ

# %% [markdown]
# https://www.dinolabs.ai/388
#
# https://yogyui.tistory.com/entry/%EA%B8%88%EC%9C%B5%EA%B0%90%EB%8F%85%EC%9B%90OPENDART-%EC%A0%84%EC%9E%90%EA%B3%B5%EC%8B%9C-Open-API-%EC%82%AC%EC%9A%A9%ED%95%98%EA%B8%B0

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://opendart.fss.or.kr/api/exctvSttus.xml?'
crtfc_key = 'ebd213d75beaeac7659874cda6ec4ec28394fdc3' #API 키
corp_code = dart.find_corp_code('삼성전자') #기업고유번호
bsns_year = 2021 #사업연도
reprt_code = 11011#보고서 코드(사업보고서)

response = requests.get(f'{url}crtfc_key={crtfc_key}&corp_code={corp_code}&bsns_year={bsns_year}&reprt_code={reprt_code}')

# %%
soup = BeautifulSoup(response.text, 'lxml')
# Out:
# /content/package/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(

# %%
print(soup)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><html><body><result><status>000</status><message>정상</message><list><rcept_no>20220308000798</rcept_no><corp_cls>Y</corp_cls><corp_code>00126380</corp_code><corp_name>삼성전자</corp_name><nm>김기남</nm><sexdstn>남</sexdstn><birth_ym>1958년 04월</birth_ym><ofcps>회장</ofcps><rgist_exctv_at>사내이사</rgist_exctv_at><fte_at>상근</fte_at><chrg_job>ㆍ대표이사ㆍ종합기술원 회장</chrg_job><main_career>ㆍUCLA 전자공학 박사ㆍ삼성전자 DS부문장</main_career><mxmm_shrholdr_relate>계열회사
# 임원</mxmm_shrholdr_relate><hffc_pd>46개월</hffc_pd><tenure_end_on>2024년 03월 22일</tenure_end_on></list><list><rcept_no>20220308000798</rcept_no><corp_cls>Y</corp_cls><corp_code>00126380</corp_code><corp_name>삼성전자</corp_name><nm>안규리</nm><sexdstn>여</sexdstn><birth_ym>1955년 03월</birth_ym><ofcps>이사</ofcps><rgist_exctv_at>사외이사</rgist_exctv_at><fte_at>비상근</fte_at><chrg_job>ㆍ사외이사후보추천위원회위원ㆍ지속가능경영위원회 위원</chrg_job><main_career>ㆍ서울대 내과학 박사
# ㆍ서울대 의과대학 신장내과
#    명예교수</main_career><mxmm_shrholdr_relate>계열회사
# ...

# %%
import pandas as pd
column = ['법인구분', '고유번호', '법인명', '성명', '성별', '출생 년월', '직위', '등기 임원 여부', 
                             '상근 여부', '담당 업무', '주요 경력', '최대 주주 관계', '재직 기간', '임기 만료 일']
df = pd.DataFrame(columns = column)

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [법인구분, 고유번호, 법인명, 성명, 성별, 출생 년월, 직위, 등기 임원 여부, 상근 여부, 담당 업무, 주요 경력, 최대 주주 관계, 재직 기간, 임기 만료 일]
# Index: []

# %%
print(a)
# Out:
# [<corp_cls>Y</corp_cls>, <corp_cls>Y</corp_cls>, <corp_cls>Y</corp_cls>, <corp_cls>Y</corp_cls>, <corp_cls>Y</corp_cls>, <corp_cls>Y</corp_cls>, <corp_cls>Y</corp_cls>, <corp_cls>Y</corp_cls>, <corp_cls>Y</corp_cls>, <corp_cls>Y</corp_cls>, <corp_cls>Y</corp_cls>]

# %%
a=soup.find('corp_cls')
print(a)
# Out:
# <corp_cls>Y</corp_cls>

# %%
b=soup.find_all('nm')
aa = []
for i in b:
  aa.append(i.text)
print(aa)
# Out:
# ['김기남', '안규리', '김한조', '김현석', '고동진', '한종희', '최윤호', '박재완', '김선욱', '박병국', '김종훈']

# %%
print(b)
# Out:
# [<nm>김기남</nm>, <nm>안규리</nm>, <nm>김한조</nm>, <nm>김현석</nm>, <nm>고동진</nm>, <nm>한종희</nm>, <nm>최윤호</nm>, <nm>박재완</nm>, <nm>김선욱</nm>, <nm>박병국</nm>, <nm>김종훈</nm>]

# %%
print(len(soup.find_all('corp_cls')))
# Out:
# 11

# %%
b=soup.find_all('nm')
aa = []
for i in range(len(b)):
  aa.append(b[i].text)
print(aa)
# Out:
# ['김기남', '안규리', '김한조', '김현석', '고동진', '한종희', '최윤호', '박재완', '김선욱', '박병국', '김종훈']

# %%
corp_cls = soup.find_all('corp_cls')
corp_code	= soup.find_all('corp_code')
corp_name	= soup.find_all('corp_name')
nm = soup.find_all('nm')
sexdstn =	soup.find_all('sexdstn')
birth_ym = soup.find_all('birth_ym')
ofcps	= soup.find_all('ofcps')
rgist_exctv_at = soup.find_all('rgist_exctv_at')
fte_at = soup.find_all('fte_at')
chrg_job = soup.find_all('chrg_job')
main_career	= soup.find_all('main_career')
mxmm_shrholdr_relate = soup.find_all('mxmm_shrholdr_relate')
hffc_pd	= soup.find_all('hffc_pd')
tenure_end_on = soup.find_all('tenure_end_on')

row=[corp_cls, corp_code, corp_name, nm, sexdstn, birth_ym, ofcps, rgist_exctv_at, chrg_job, 
     main_career, mxmm_shrholdr_relate, hffc_pd, tenure_end_on]

'''
for i in range(len(soup.find_all('corp_cls'))):
  for j in range(len(row)):
    df.iloc[i, j]=row[j][i].text
'''

'''
for i in range(len(soup.find_all('corp_cls'))):
  df= df.append({'법인구분':  corp_cls[i].text,
                 '고유번호': corp_code[i].text,
                 '법인명':  corp_name[i].text,
                 '성명':  nm[i].text,
                 '성별':  sexdstn[i].text,
                 '출생 년월': birth_ym[i].text,
                 '직위': ofcps[i].text,
                 '등기 임원 여부': rgist_exctv_at[i].text,
                 '상근 여부': fte_at[i].text,
                 '담당 업무': chrg_job[i].text,
                 '주요 경력': main_career[i].text,
                 '최대 주주 관계':  mxmm_shrholdr_relate[i].text,
                 '재직 기간':  hffc_pd[i].text,
                 '임기 만료 일': tenure_end_on[i].text}, ignore_index=True)
'''

for i in range(len(soup.find_all('corp_cls'))):
  df2 = pd.DataFrame.from_dict({'법인구분':  corp_cls[i].text,
                 '고유번호': corp_code[i].text,
                 '법인명':  corp_name[i].text,
                 '성명':  nm[i].text,
                 '성별':  sexdstn[i].text,
                 '출생 년월': birth_ym[i].text,
                 '직위': ofcps[i].text,
                 '등기 임원 여부': rgist_exctv_at[i].text,
                 '상근 여부': fte_at[i].text,
                 '담당 업무': chrg_job[i].text,
                 '주요 경력': main_career[i].text,
                 '최대 주주 관계':  mxmm_shrholdr_relate[i].text,
                 '재직 기간':  hffc_pd[i].text,
                 '임기 만료 일': tenure_end_on[i].text}, orient='index')
  #df= pd.concat(df, df2,ignore_index=True )
  df.iloc[i, :] = df2
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-102-8e5d3e4b7349> in <cell line: 43>()
#      57                  '임기 만료 일': tenure_end_on[i].text}, orient='index')
#      58   #df= pd.concat(df, df2,ignore_index=True )
# ---> 59   df.iloc[i, :] = df2
#
# /content/package/pandas/core/indexing.py in __setitem__(self, key, value)
#     844             key = com.apply_if_callable(key, self.obj)
#     845         indexer = self._get_setitem_indexer(key)
# --> 846         self._has_valid_setitem_indexer(key)
#     847
#     848         iloc = self if self.name == "iloc" else self.obj.iloc
#
# /content/package/pandas/core/indexing.py in _has_valid_setitem_indexer(self, indexer)
#    1548             elif is_integer(i):
#    1549                 if i >= len(ax):
# -> 1550                     raise IndexError("iloc cannot enlarge its target object")
# ...
