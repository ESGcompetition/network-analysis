# %%
import pandas as pd

dasin_excutive = pd.read_csv('df_executive.csv')

# %%
dasin_excutive.head(3)
# Out:
#              접수번호 법인구분    고유번호     법인명   이름 성별       생년월일      직위 등기임원여부 상근여부  \
# 0  20210317000643    Y  156859  다올투자증권  이병철  남  1969년 03월  대표\n이사   등기임원   상근
# 1  20210317000643    Y  156859  다올투자증권  최석종  남  1961년 06월  대표\n이사   등기임원   상근
# 2  20210317000643    Y  156859  다올투자증권  김형남  남  1956년 03월  사내\n이사   등기임원   상근
#
#       담당업무                                   주요경력 최대주주와의관계         재직기간  \
# 0  총괄\n부회장               고려대 경영학(중퇴)\n다올인베스트먼트 사장   최대주주본인  2016.07.13~
# 1       사장  고려대 정치외교학\n연세대경영대학원 MBA\n교보증권 IB금융본부장   발행회사임원  2016.06.09~
# 2   감사\n위원   연세대 행정대학원\n하나자산신탁 상근감사\n삼성선물(주) 상근감사   발행회사임원  2018.03.30~
#
#            임기만료일  보고서연도
# 0  2022년 03월 26일   2020
# 1  2022년 03월 26일   2020
# 2  2021년 03월 29일   2020

# %%
name_split = dasin_excutive["주요경력"].str.split("\n")
dasin_excutive["주요경력"] = name_split.str.get(0)
dasin_excutive.head(3)
# Out:
#              접수번호 법인구분    고유번호     법인명   이름 성별       생년월일      직위 등기임원여부 상근여부  \
# 0  20210317000643    Y  156859  다올투자증권  이병철  남  1969년 03월  대표\n이사   등기임원   상근
# 1  20210317000643    Y  156859  다올투자증권  최석종  남  1961년 06월  대표\n이사   등기임원   상근
# 2  20210317000643    Y  156859  다올투자증권  김형남  남  1956년 03월  사내\n이사   등기임원   상근
#
#       담당업무         주요경력 최대주주와의관계         재직기간          임기만료일  보고서연도
# 0  총괄\n부회장  고려대 경영학(중퇴)   최대주주본인  2016.07.13~  2022년 03월 26일   2020
# 1       사장    고려대 정치외교학   발행회사임원  2016.06.09~  2022년 03월 26일   2020
# 2   감사\n위원    연세대 행정대학원   발행회사임원  2018.03.30~  2021년 03월 29일   2020

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

for i in range(len(dasin_excutive)):
    G.add_node(dasin_excutive.loc[i, '이름'])

# %%
col = []
row = []
for i in range(len(dasin_excutive)):
    col.append(dasin_excutive.loc[i, '이름'])
    row.append(dasin_excutive.loc[i, '이름'])


df = pd.DataFrame(columns=col, index=row)
df
# Out:
#               이병철  최석종  김형남  박동수 Benny\nChung  정유신  이석환 Ting\nChen  이현주  이병철  \
# 이병철           NaN  NaN  NaN  NaN          NaN  NaN  NaN        NaN  NaN  NaN
# 최석종           NaN  NaN  NaN  NaN          NaN  NaN  NaN        NaN  NaN  NaN
# 김형남           NaN  NaN  NaN  NaN          NaN  NaN  NaN        NaN  NaN  NaN
# 박동수           NaN  NaN  NaN  NaN          NaN  NaN  NaN        NaN  NaN  NaN
# Benny\nChung  NaN  NaN  NaN  NaN          NaN  NaN  NaN        NaN  NaN  NaN
# ...           ...  ...  ...  ...          ...  ...  ...        ...  ...  ...
# 김재식           NaN  NaN  NaN  NaN          NaN  NaN  NaN        NaN  NaN  NaN
# 최선화           NaN  NaN  NaN  NaN          NaN  NaN  NaN        NaN  NaN  NaN
# 이군희           NaN  NaN  NaN  NaN          NaN  NaN  NaN        NaN  NaN  NaN
# 이순우           NaN  NaN  NaN  NaN          NaN  NaN  NaN        NaN  NaN  NaN
# 박연채           NaN  NaN  NaN  NaN          NaN  NaN  NaN        NaN  NaN  NaN
#
# ...

# %%
ds_ex_pr = daishin_executive.drop(columns = ['접수번호', '법인구분', '고유번호', '법인명'])
