# %%
import OpenDartReader

api_key = '7f942045d438f45c28bc2707063b8838be98f7e6'

dart = OpenDartReader(api_key)

# %%
dart.list('삼성전자')
# Out:
#      corp_code corp_name stock_code corp_cls              report_nm  \
# 0     00126380      삼성전자     005930        Y      주식등의대량보유상황보고서(일반)
# 1     00126380      삼성전자     005930        Y         최대주주등소유주식변동신고서
# 2     00126380      삼성전자     005930        Y      주식등의대량보유상황보고서(일반)
# 3     00126380      삼성전자     005930        Y           기타경영사항(자율공시)
# 4     00126380      삼성전자     005930        Y           기타경영사항(자율공시)
# ...        ...       ...        ...      ...                    ...
# 5733  00126380      삼성전자     005930        Y           채무보증(담보제공포함)
# 5734  00126380      삼성전자     005930        Y          최대주주등을위한금전의대여
# 5735  00126380      삼성전자     005930        Y        감사보고서 (1999.12)
# 5736  00126380      삼성전자     005930        Y  [기재정정]반기보고서 (1999.06)
# 5737  00126380      삼성전자     005930        Y  [기재정정]사업보고서 (1998.12)
#
#             rcept_no  flr_nm  rcept_dt rm
# 0     20230504000774    삼성물산  20230504
# 1     20230503800466    삼성전자  20230503  유
# ...

# %%
dart.major_shareholders('삼성전자')
# Out:
#           rcept_no    rcept_dt corp_code corp_name report_tp  \
# 0   20210507000809  2021-05-07  00126380      삼성전자        일반
# 1   20210730000519  2021-07-30  00126380      삼성전자        일반
# 2   20210806000286  2021-08-06  00126380      삼성전자        일반
# 3   20210924000389  2021-09-24  00126380      삼성전자        일반
# 4   20211001000488  2021-10-01  00126380      삼성전자        일반
# 5   20211008000519  2021-10-08  00126380      삼성전자        일반
# 6   20211029000589  2021-10-29  00126380      삼성전자        일반
# 7   20211103000100  2021-11-03  00126380      삼성전자        약식
# 8   20220128000648  2022-01-28  00126380      삼성전자        일반
# 9   20220323001259  2022-03-23  00126380      삼성전자        일반
# 10  20220328001085  2022-03-28  00126380      삼성전자        일반
# 11  20220411003043  2022-04-11  00126380      삼성전자        약식
# 12  20220422000748  2022-04-22  00126380      삼성전자        일반
# 13  20220429001445  2022-04-29  00126380      삼성전자        일반
# ...

# %%
dart.report('삼성전자', '최대주주', 2022)
# Out:
#           rcept_no corp_cls corp_code corp_name stock_knd             nm  \
# 0   20230307000542        Y  00126380      삼성전자       보통주        삼성생명보험㈜
# 1   20230307000542        Y  00126380      삼성전자       우선주            홍라희
# 2   20230307000542        Y  00126380      삼성전자       보통주            이재용
# 3   20230307000542        Y  00126380      삼성전자       우선주            이재용
# 4   20230307000542        Y  00126380      삼성전자       보통주            이부진
# 5   20230307000542        Y  00126380      삼성전자       우선주            이부진
# 6   20230307000542        Y  00126380      삼성전자       보통주            이서현
# 7   20230307000542        Y  00126380      삼성전자       우선주            이서현
# 8   20230307000542        Y  00126380      삼성전자       보통주            한종희
# 9   20230307000542        Y  00126380      삼성전자       보통주            경계현
# 10  20230307000542        Y  00126380      삼성전자       보통주            노태문
# 11  20230307000542        Y  00126380      삼성전자       우선주        삼성생명보험㈜
# ...

# %%
dart.report('삼성전자', '임원', 2022)
# Out:
#           rcept_no corp_cls corp_code corp_name   nm sexdstn   birth_ym ofcps  \
# 0   20230307000542        Y  00126380      삼성전자  한종희       남  1962년 03월   부회장
# 1   20230307000542        Y  00126380      삼성전자  허은녕       남  1964년 08월    이사
# 2   20230307000542        Y  00126380      삼성전자  유명희       여  1967년 06월    이사
# 3   20230307000542        Y  00126380      삼성전자  경계현       남  1963년 03월    사장
# 4   20230307000542        Y  00126380      삼성전자  노태문       남  1968년 09월    사장
# 5   20230307000542        Y  00126380      삼성전자  박학규       남  1964년 11월    사장
# 6   20230307000542        Y  00126380      삼성전자  이정배       남  1967년 02월    사장
# 7   20230307000542        Y  00126380      삼성전자  김한조       남  1956년 07월    이사
# 8   20230307000542        Y  00126380      삼성전자  김선욱       여  1952년 12월    이사
# 9   20230307000542        Y  00126380      삼성전자  김종훈       남  1960년 08월    이사
# 10  20230307000542        Y  00126380      삼성전자  김준성       남  1967년 10월    이사
#
# ...

# %%
dart.report('삼성전자', '직원', 2022)
# Out:
#          rcept_no corp_cls corp_code corp_name sexdstn fo_bbm  \
# 0  20230307000542        Y  00126380      삼성전자       남     DX
# 1  20230307000542        Y  00126380      삼성전자       여     DX
# 2  20230307000542        Y  00126380      삼성전자       남     DS
# 3  20230307000542        Y  00126380      삼성전자       여     DS
# 4  20230307000542        Y  00126380      삼성전자       남   성별합계
# 5  20230307000542        Y  00126380      삼성전자       여   성별합계
#
#   reform_bfe_emp_co_rgllbr reform_bfe_emp_co_cnttk reform_bfe_emp_co_etc  \
# 0                        -                       -                     -
# 1                        -                       -                     -
# 2                        -                       -                     -
# 3                        -                       -                     -
# 4                        -                       -                     -
# 5                        -                       -                     -
#
# ...

# %%
samsung_power_people = dart.report('삼성전자', '최대주주', 2022)

# %%
samsung_power_people
# Out:
#           rcept_no corp_cls corp_code corp_name stock_knd             nm  \
# 0   20230307000542        Y  00126380      삼성전자       보통주        삼성생명보험㈜
# 1   20230307000542        Y  00126380      삼성전자       우선주            홍라희
# 2   20230307000542        Y  00126380      삼성전자       보통주            이재용
# 3   20230307000542        Y  00126380      삼성전자       우선주            이재용
# 4   20230307000542        Y  00126380      삼성전자       보통주            이부진
# 5   20230307000542        Y  00126380      삼성전자       우선주            이부진
# 6   20230307000542        Y  00126380      삼성전자       보통주            이서현
# 7   20230307000542        Y  00126380      삼성전자       우선주            이서현
# 8   20230307000542        Y  00126380      삼성전자       보통주            한종희
# 9   20230307000542        Y  00126380      삼성전자       보통주            경계현
# 10  20230307000542        Y  00126380      삼성전자       보통주            노태문
# 11  20230307000542        Y  00126380      삼성전자       우선주        삼성생명보험㈜
# ...
