# %%
import OpenDartReader

api_key = '7f942045d438f45c28bc2707063b8838be98f7e6'

dart = OpenDartReader(api_key)

# %%
data = dart.report('삼성전자', '임원', 2022)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import networkx as nx

# %%
data.head()
# Out:
#          rcept_no corp_cls corp_code corp_name   nm sexdstn   birth_ym ofcps  \
# 0  20230307000542        Y  00126380      삼성전자  한종희       남  1962년 03월   부회장
# 1  20230307000542        Y  00126380      삼성전자  허은녕       남  1964년 08월    이사
# 2  20230307000542        Y  00126380      삼성전자  유명희       여  1967년 06월    이사
# 3  20230307000542        Y  00126380      삼성전자  경계현       남  1963년 03월    사장
# 4  20230307000542        Y  00126380      삼성전자  노태문       남  1968년 09월    사장
#
#   rgist_exctv_at fte_at                 chrg_job  \
# 0           사내이사     상근  ㆍ대표이사   (DX 부문 경영전반 총괄)
# 1           사외이사    비상근            ㆍ지속가능경영위원회 위원
# 2           사외이사    비상근            ㆍ지속가능경영위원회 위원
# 3           사내이사     상근  ㆍ대표이사   (DS 부문 경영전반 총괄)
# 4           사내이사     상근                  ㆍMX사업부장
#
#                                        main_career mxmm_shrholdr_relate  \
# 0                          ㆍ인하대 전자공학 학사ㆍ삼성전자 DX부문장             계열회사\n임원
# ...

# %%
print('임원 :' + data['nm'])
# Out:
# 0     임원 :한종희
# 1     임원 :허은녕
# 2     임원 :유명희
# 3     임원 :경계현
# 4     임원 :노태문
# 5     임원 :박학규
# 6     임원 :이정배
# 7     임원 :김한조
# 8     임원 :김선욱
# 9     임원 :김종훈
# 10    임원 :김준성
# Name: nm, dtype: object

# %%
data = dart.report('삼성전자', '최대주주', 2022)

# %%
data.head()
# Out:
#          rcept_no corp_cls corp_code corp_name stock_knd       nm  \
# 0  20230307000542        Y  00126380      삼성전자       보통주  삼성생명보험㈜
# 1  20230307000542        Y  00126380      삼성전자       우선주      홍라희
# 2  20230307000542        Y  00126380      삼성전자       보통주      이재용
# 3  20230307000542        Y  00126380      삼성전자       우선주      이재용
# 4  20230307000542        Y  00126380      삼성전자       보통주      이부진
#
#         relate bsis_posesn_stock_co bsis_posesn_stock_qota_rt  \
# 0      최대주주 본인          508,157,148                      8.51
# 1  최대주주의 특수관계인              206,633                      0.03
# 2  최대주주의 특수관계인           97,414,196                      1.63
# 3  최대주주의 특수관계인              137,757                      0.02
# 4      계열회사 임원           55,394,044                      0.93
#
#   trmend_posesn_stock_co trmend_posesn_stock_qota_rt rm
# 0            508,157,148                        8.51  -
# 1                206,633                        0.03  -
# ...

# %%
data
# Out:
#           rcept_no corp_cls corp_code corp_name stock_knd             nm  \
# 0   20230307000542        Y  00126380      삼성전자       보통주        삼성생명보험㈜
# 1   20230307000542        Y  00126380      삼성전자       우선주            홍라희
# 2   20230307000542        Y  00126380      삼성전자       보통주            이재용
# 3   20230307000542        Y  00126380      삼성전자       우선주            이재용
# 4   20230307000542        Y  00126380      삼성전자       보통주            이부진
# 5   20230307000542        Y  00126380      삼성전자       우선주            이부진
# 6   20230307000542        Y  00126380      삼성전자       보통주            이서현
# 7   20230307000542        Y  00126380      삼성전자       우선주            이서현
# 8   20230307000542        Y  00126380      삼성전자       보통주            한종희
# 9   20230307000542        Y  00126380      삼성전자       보통주            경계현
# 10  20230307000542        Y  00126380      삼성전자       보통주            노태문
# 11  20230307000542        Y  00126380      삼성전자       우선주        삼성생명보험㈜
# ...

# %%
print('임원 :' + data['nm'])
# Out:
# 0           임원 :삼성생명보험㈜
# 1               임원 :홍라희
# 2               임원 :이재용
# 3               임원 :이재용
# 4               임원 :이부진
# 5               임원 :이부진
# 6               임원 :이서현
# 7               임원 :이서현
# 8               임원 :한종희
# 9               임원 :경계현
# 10              임원 :노태문
# 11          임원 :삼성생명보험㈜
# 12              임원 :박학규
# 13              임원 :이정배
# 14              임원 :김한조
# 15              임원 :김기남
# 16              임원 :김현석
# 17              임원 :고동진
# 18              임원 :안규리
# 19              임원 :박병국
# 20    임원 :삼성생명보험㈜(특별계정)
# 21    임원 :삼성생명보험㈜(특별계정)
# 22            임원 :삼성물산㈜
# 23        임원 :삼성화재해상보험㈜
# 24           임원 :삼성복지재단
# 25           임원 :삼성문화재단
# 26              임원 :홍라희
# 27                임원 :계
# 28                임원 :계
# Name: nm, dtype: object

# %%
data_1 = data[['nm', 'bsis_posesn_stock_co']]

# %%
data_1
# Out:
#                nm bsis_posesn_stock_co
# 0         삼성생명보험㈜          508,157,148
# 1             홍라희              206,633
# 2             이재용           97,414,196
# 3             이재용              137,757
# 4             이부진           55,394,044
# 5             이부진              137,755
# 6             이서현           55,394,044
# 7             이서현              137,755
# 8             한종희                5,000
# 9             경계현                    0
# 10            노태문                    0
# 11        삼성생명보험㈜               43,950
# 12            박학규                    0
# 13            이정배                    0
# 14            김한조                2,175
# 15            김기남              210,000
# 16            김현석               99,750
# 17            고동진               75,000
# 18            안규리                3,800
# 19            박병국                1,000
# 20  삼성생명보험㈜(특별계정)           13,860,804
# 21  삼성생명보험㈜(특별계정)              548,463
# 22          삼성물산㈜          298,818,100
# ...

# %%
import matplotlib.font_manager as fm

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'

g = nx.Graph()
g = nx.from_pandas_edgelist(data_1, source = 'nm', target = 'bsis_posesn_stock_co')
print(nx.info(g))

plt.figure(figsize=(20, 20))
pos = nx.spring_layout(g, k = 0.15)
nx.draw_networkx(g,pos, node_size = 25, node_color = 'blue', font_family='Malgun Gothic')
plt.show()
# Out:
# Graph with 46 nodes and 29 edges

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# []

# %%
print(mpl.rcParams['font.family'])
print(mpl.rcParams['font.size'])
# Out:
# ['NanumGothic']
# 12.0
